# %% [markdown]
# # 1. 데이터 불러오기

# %%
import os
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\awdrg\Documents\Documents\텀플 데이터\3rd 주요계정강화\4. CSV파일화\제조업_주요계정 강화 - 복사본 - 복사본.csv',
           encoding='cp949', thousands = ',')
df.head(3)
# Out:
#        Name   총자산대비현금  산업평균대비현금   매출채권회전율    매출총이익률  대손률  총자산대비매출채권  \
# 0      삼성전자  0.091490  0.027070  6.867633  0.404834  0.0   0.095432
# 1  LG에너지솔루션  0.053984 -0.010436  6.125292  0.218396  0.0   0.122641
# 2  삼성바이오로직스  0.005949 -0.058471  0.000000  0.463296  0.0   0.000000
#
#    산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  ...     매출원가율   총자산대비재고  산업평균대비재고  \
# 0   -0.030269   0.235830     0.199518  ...  0.595166  0.097005 -0.010787
# 1   -0.003060   0.011713     0.000045  ...  0.781604  0.163936  0.056144
# 2   -0.125701   0.169527     0.163116  ...  0.536704  0.127085  0.019293
#
#       유효이자율   단기유효이자율  총자산대비차입금  산업평균대비차입금     역마진여부    단기역마진여부  감사의견
# 0  0.023463  0.031527  0.043111  -0.290929 -0.010758  -0.016510  적정의견
# 1  0.009615  0.058460  0.293265  -0.040775  0.068816  20.401709  적정의견
# 2  0.011377  0.255612  0.162201  -0.171839 -0.004230  -0.248185  적정의견
#
# [3 rows x 35 columns]

# %%
df.shape
# Out:
# (25040, 35)

# %% [markdown]
# # 2. Null 값 제거

# %%
df = df.dropna(subset = ['Name'])
df
# Out:
#              Name   총자산대비현금  산업평균대비현금    매출채권회전율    매출총이익률       대손률  \
# 0            삼성전자  0.091490  0.027070   6.867633  0.404834  0.000000
# 1        LG에너지솔루션  0.053984 -0.010436   6.125292  0.218396  0.000000
# 2        삼성바이오로직스  0.005949 -0.058471   0.000000  0.463296  0.000000
# 3          SK하이닉스  0.052476 -0.011943   5.201066  0.440771  0.000000
# 4           삼성SDI  0.090027  0.025608   6.965864  0.227077  0.000080
# ...           ...       ...       ...        ...       ...       ...
# 25034   세미켓코리아(주)  0.126028  0.061609  11.039697  0.177957  0.000000
# 25035   주식회사스타스테크  0.011082 -0.053337  31.219595  0.383469  0.000000
# 25036  주식회사글로벌에스텍  0.021297 -0.043122   0.000000  0.592762  0.000000
# 25038     (주)성지화학  0.098020  0.033600   3.343085  0.258193  0.068897
# 25039     (주)마이벨로  0.087534  0.023115   4.601281  0.135155  0.010284
#
#        총자산대비매출채권  산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  ...     매출원가율   총자산대비재고  \
# ...

# %%
df= df.dropna(axis = 1,how = 'all')
df.head(3)
# Out:
#        Name   총자산대비현금  산업평균대비현금   매출채권회전율    매출총이익률  대손률  총자산대비매출채권  \
# 0      삼성전자  0.091490  0.027070  6.867633  0.404834  0.0   0.095432
# 1  LG에너지솔루션  0.053984 -0.010436  6.125292  0.218396  0.0   0.122641
# 2  삼성바이오로직스  0.005949 -0.058471  0.000000  0.463296  0.0   0.000000
#
#    산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  ...     매출원가율   총자산대비재고  산업평균대비재고  \
# 0   -0.030269   0.235830     0.199518  ...  0.595166  0.097005 -0.010787
# 1   -0.003060   0.011713     0.000045  ...  0.781604  0.163936  0.056144
# 2   -0.125701   0.169527     0.163116  ...  0.536704  0.127085  0.019293
#
#       유효이자율   단기유효이자율  총자산대비차입금  산업평균대비차입금     역마진여부    단기역마진여부  감사의견
# 0  0.023463  0.031527  0.043111  -0.290929 -0.010758  -0.016510  적정의견
# 1  0.009615  0.058460  0.293265  -0.040775  0.068816  20.401709  적정의견
# 2  0.011377  0.255612  0.162201  -0.171839 -0.004230  -0.248185  적정의견
#
# [3 rows x 35 columns]

# %%
df.isnull().sum()
# Out:
# Name               0
# 총자산대비현금            0
# 산업평균대비현금           0
# 매출채권회전율            0
# 매출총이익률             0
# 대손률                0
# 총자산대비매출채권          0
# 산업평균대비매출채권         0
# 총자산대비금융자산          0
# 총자산대비단기금융자산        0
# 금융자산수익률            0
# 단기금융자산수익률          0
# 총자산대비유가증권          0
# 유가증권수익률            0
# 산업평균대비유가증권         0
# 유형자산감가상각률          0
# 산업평균대비유형자산감가상각률    0
# 총자산대비유형자산          0
# 산업평균대비유형자산         0
# 무형자산상각률            0
# 산업평균대비무형자산상각률      0
# 총자산대비무형자산          0
# 개발비계상비율            0
# 산업평균대비무형자산         0
# 재고자산회전율            0
# 매출원가율              0
# 총자산대비재고            0
# 산업평균대비재고           0
# 유효이자율              0
# 단기유효이자율            0
# 총자산대비차입금           0
# 산업평균대비차입금          0
# 역마진여부              0
# 단기역마진여부            0
# 감사의견               0
# dtype: int64

# %%
(round(df.isnull().sum()/len(df),2)).to_frame()
# Out:
#                    0
# Name             0.0
# 총자산대비현금          0.0
# 산업평균대비현금         0.0
# 매출채권회전율          0.0
# 매출총이익률           0.0
# 대손률              0.0
# 총자산대비매출채권        0.0
# 산업평균대비매출채권       0.0
# 총자산대비금융자산        0.0
# 총자산대비단기금융자산      0.0
# 금융자산수익률          0.0
# 단기금융자산수익률        0.0
# 총자산대비유가증권        0.0
# 유가증권수익률          0.0
# 산업평균대비유가증권       0.0
# 유형자산감가상각률        0.0
# 산업평균대비유형자산감가상각률  0.0
# 총자산대비유형자산        0.0
# 산업평균대비유형자산       0.0
# 무형자산상각률          0.0
# 산업평균대비무형자산상각률    0.0
# 총자산대비무형자산        0.0
# 개발비계상비율          0.0
# 산업평균대비무형자산       0.0
# 재고자산회전율          0.0
# 매출원가율            0.0
# 총자산대비재고          0.0
# 산업평균대비재고         0.0
# 유효이자율            0.0
# 단기유효이자율          0.0
# 총자산대비차입금         0.0
# 산업평균대비차입금        0.0
# 역마진여부            0.0
# 단기역마진여부          0.0
# 감사의견             0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13731 entries, 0 to 25039
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             13731 non-null  object
#  1   총자산대비현금          13731 non-null  float64
#  2   산업평균대비현금         13731 non-null  float64
#  3   매출채권회전율          13731 non-null  float64
#  4   매출총이익률           13731 non-null  float64
#  5   대손률              13731 non-null  float64
#  6   총자산대비매출채권        13731 non-null  float64
#  7   산업평균대비매출채권       13731 non-null  float64
#  8   총자산대비금융자산        13731 non-null  float64
#  9   총자산대비단기금융자산      13731 non-null  float64
#  10  금융자산수익률          13731 non-null  float64
#  11  단기금융자산수익률        13731 non-null  float64
#  12  총자산대비유가증권        13731 non-null  float64
#  13  유가증권수익률          13731 non-null  float64
#  14  산업평균대비유가증권       13731 non-null  float64
#  15  유형자산감가상각률        13731 non-null  float64
# ...

# %%
df.describe()
# Out:
#             총자산대비현금      산업평균대비현금       매출채권회전율        매출총이익률           대손률  \
# count  13731.000000  13731.000000  1.373100e+04  13731.000000  13731.000000
# mean       0.100736      0.036317  4.794499e+02      0.122938      0.052192
# std        0.121699      0.121699  4.941696e+04      5.678040      2.761660
# min       -0.022579     -0.086999 -2.536146e+02   -647.240952   -215.518518
# 25%        0.021218     -0.043201  4.712436e+00      0.095384      0.000000
# 50%        0.064419      0.000000  6.815407e+00      0.163641      0.001079
# 75%        0.137615      0.073195  1.044269e+01      0.265856      0.010101
# max        4.805113      4.740694  5.767907e+06      3.211725    179.021739
#
#           총자산대비매출채권    산업평균대비매출채권     총자산대비금융자산   총자산대비단기금융자산       금융자산수익률  \
# count  13731.000000  1.373100e+04  13731.000000  13731.000000  13731.000000
# mean       0.148998  2.329717e-02      0.110779      0.065974     10.912683
# ...

# %%
df['감사의견'].value_counts().to_frame()
# Out:
#                 감사의견
# 적정의견           12243
# 한정의견(감사범위제한)     702
# 0                540
# 의견거절(불확실성)       131
# 의견거절(감사범위제한)      74
# 한정의견(불확실성)        20
# 한정의견(GAAP위반)      15
# 부적정의견(GAAP위반)      6

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 폰트 설정 방법 1
import matplotlib.pyplot as plt

# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='Malgun Gothic') # For Windows
print(plt.rcParams['font.family'])

# %matplotlib inline
# 브라우저에서 바로 이미지를 그린다.
# Out:
# ['Malgun Gothic']

# %%
plt.rcParams["font.size"]=20

f, ax = plt.subplots(figsize=(20,8))

sns.countplot(y="감사의견", data=df)
plt.xlabel('감사의견')
plt.title('Audit Opinion Distribution')
plt.show()

# %%
df = df.drop(df[df['감사의견']=='0'].index, axis = 0)
df['감사의견'].value_counts().to_frame()
# Out:
#                 감사의견
# 적정의견           12243
# 한정의견(감사범위제한)     702
# 의견거절(불확실성)       131
# 의견거절(감사범위제한)      74
# 한정의견(불확실성)        20
# 한정의견(GAAP위반)      15
# 부적정의견(GAAP위반)      6

# %%
plt.rcParams["font.size"]=20

f, ax = plt.subplots(figsize=(20,8))

sns.countplot(y="감사의견", data=df)
plt.xlabel('감사의견')
plt.title('Audit Opinion Distribution')
plt.show()

# %%
df['감사의견']=df['감사의견'].apply(lambda x : 0 if x == '적정의견' 
                            else (0 if x[0:4] == '한정의견' else 1 ))

# %%
df['감사의견'].value_counts()
# Out:
# 0    12980
# 1      211
# Name: 감사의견, dtype: int64

# %%
round(df['감사의견'].value_counts()/len(df),2)
# Out:
# 0    0.98
# 1    0.02
# Name: 감사의견, dtype: float64

# %%
df.shape
# Out:
# (13191, 35)

# %% [markdown]
# # 3. EDA

# %% [markdown]
# 아직 폰트 해결을 못했다.

# %% [markdown]
# 3.1. 감사의견 분포

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 폰트깨짐 해결

# %% [markdown]
# #### Nanum 폰트가 인식될 때 'Nanum Malgun Gothic' 이 아니라 'Malgun Gothic' 으로 인식이 되는 것이 었습니다.

# %%
# 폰트 설정 방법 1
import matplotlib.pyplot as plt

# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='Malgun Gothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['Malgun Gothic']

# %%
sns.countplot(df['감사의견'])
# plt.xlabel('Audit Opinion')
plt.xlabel('감사의견')
plt.title('Audit Opinion Distribution')

print('df.shape :' ,df.shape)
# Out:
# df.shape : (13191, 35)

# %%
df['감사의견'].value_counts()
# Out:
# 0    12980
# 1      211
# Name: 감사의견, dtype: int64

# %% [markdown]
# * 이름은 이거 하고 떼어내야

# %%
df[df['감사의견']==1]['Name']
# Out:
# 321          스마트솔루션즈
# 474            인트로메딕
# 504            좋은사람들
# 674           비보존 제약
# 768              휴센텍
#             ...
# 24860         주식회사금명
# 24861      주식회사다올지앤씨
# 24927       (주)G.M식품
# 24967       제이에코주식회사
# 25018    세븐브로이맥주주식회사
# Name: Name, Length: 211, dtype: object

# %%
df.drop('Name', axis = 1, inplace = True)

# %%
df.shape
# Out:
# (13191, 34)

# %% [markdown]
# 3.2. 히스토그램

# %%
plt.rcParams["font.size"]=20
df.hist(figsize = (35,30), bins = 50, xlabelsize=20, ylabelsize=20)
plt.show()

# %% [markdown]
# 3.3. 상관관계분석

# %%
f, ax = plt.subplots(figsize=(30, 25))

mat = df.corr('spearman')
mask = np.triu(np.ones_like(mat, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(mat, mask=mask, cmap=cmap, vmax=1, center=0, annot = True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# * 순위확인

# %%
mat['감사의견'].abs().sort_values(ascending = False)[1:11].to_frame()
# Out:
#                 감사의견
# 매출총이익률      0.084303
# 산업평균대비현금    0.076299
# 총자산대비현금     0.076299
# 매출원가율       0.075488
# 유효이자율       0.067076
# 총자산대비차입금    0.066512
# 산업평균대비차입금   0.066512
# 총자산대비매출채권   0.055269
# 산업평균대비매출채권  0.055269
# 총자산대비재고     0.053609

# %%
mat['감사의견'].sort_values(ascending = False)[1:6].to_frame()

# 오히려 토지를 차감 안하는게 낫다는 것인가?
# Out:
#                감사의견
# 매출원가율      0.075488
# 유효이자율      0.067076
# 총자산대비차입금   0.066512
# 산업평균대비차입금  0.066512
# 총자산대비유형자산  0.013385

# %%
mat['감사의견'].sort_values(ascending = True)[:5].to_frame()
# Out:
#                 감사의견
# 매출총이익률     -0.084303
# 총자산대비현금    -0.076299
# 산업평균대비현금   -0.076299
# 산업평균대비매출채권 -0.055269
# 총자산대비매출채권  -0.055269

# %% [markdown]
# 3.4. 피쳐별 분포확인

# %%
plt.figure(figsize = (20,15))
ax =sns.boxplot(data = df, orient="h")
ax.set_title('Audit Data Boxplots', fontsize = 18)
ax.set(xscale="log")
plt.show()
# Out:
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# ...

# %% [markdown]
# 3.5. 감사의견별 분포확인

# %%
plt.rcParams["font.size"]=14

# %%
import math

def draw_boxplot(dataset, horizental_number, vertical_number):
        
    for j in range(vertical_number):
        cols = dataset.columns[j*horizental_number:(j+1)*horizental_number]

        n=0
        f, axes = plt.subplots(ncols=horizental_number, figsize=(24,24/horizental_number))

        for i in cols:
            sns.boxplot(x= '감사의견', y= i , data=dataset, ax=axes[n])
            axes[n].set_title(i, fontsize=16)
            axes[n].set_ylabel("")
            
            n=n+1
        plt.show()
        
draw_boxplot(df, 6, math.ceil(df.shape[1]/6))

# %% [markdown]
# * 감사의견 = 1 인 값만 히스토그램 그린 것

# %%
def draw_distplot(dataset, horizental_number, vertical_number):
    
    for j in range(vertical_number):

        f, axes = plt.subplots(1,horizental_number, figsize=(24, 24/horizental_number))

        cols = dataset.columns[j*horizental_number:(j+1)*horizental_number]
        colors = ['#FB8861','#56F9BB','#C5B3F9']*2

        n = 0

        for i, l in zip(cols, colors):
            sns.distplot(dataset[i].loc[df['감사의견']== 1] ,ax= axes[n], color= l) # fit=norm 왜 안되냐?
            axes[n].set_title(i + '\n (Audit opinion = 1)', fontsize=16)
            axes[n].set_ylabel("")
            
            n+=1
        plt.show()
        
draw_distplot(df, 6, math.ceil(df.shape[1]/6))

# %%
for j,i in enumerate(range(df.shape[1])):
    
    print('{0}. {1}:' .format(j,df.columns[i]))
    print("    1. Skewness: %f" % df.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df.iloc[:,i].kurt())
    
# df[i] 를 하면  self._engine.get_loc(casted_key) 오류 발생
    # => i는 iloc으로 찾아야
# Out:
# 0. 총자산대비현금:
#     1. Skewness: 6.312096
#     2. Kurtosis: 173.569397
#
# 1. 산업평균대비현금:
#     1. Skewness: 6.312096
#     2. Kurtosis: 173.569396
#
# 2. 매출채권회전율:
#     1. Skewness: 113.579719
#     2. Kurtosis: 12985.232143
#
# 3. 매출총이익률:
#     1. Skewness: -106.846560
#     2. Kurtosis: 11848.983345
#
# 4. 대손률:
#     1. Skewness: -6.071353
#     2. Kurtosis: 4184.344400
#
# 5. 총자산대비매출채권:
#     1. Skewness: 1.595100
#     2. Kurtosis: 4.300513
#
# 6. 산업평균대비매출채권:
#     1. Skewness: 1.595100
#     2. Kurtosis: 4.300513
#
# 7. 총자산대비금융자산:
#     1. Skewness: 2.136425
#     2. Kurtosis: 5.194538
#
# 8. 총자산대비단기금융자산:
#     1. Skewness: 2.828640
#     2. Kurtosis: 9.602409
#
# 9. 금융자산수익률:
#     1. Skewness: 78.914599
#     2. Kurtosis: 6656.177053
#
# 10. 단기금융자산수익률:
#     1. Skewness: 104.091539
#     2. Kurtosis: 11333.913444
#
# 11. 총자산대비유가증권:
#     1. Skewness: 4.501152
#     2. Kurtosis: 25.583312
#
# 12. 유가증권수익률:
#     1. Skewness: 83.432927
#     2. Kurtosis: 7200.475004
#
# ...

# %%
# 마지막 값만 남는 이유: 변수를 for문 안에 설정해서 초기화됨.

# %% [markdown]
# # 4. 이상치 제거

# %%
for col in df:
    print(col)
# Out:
# 총자산대비현금
# 산업평균대비현금
# 매출채권회전율
# 매출총이익률
# 대손률
# 총자산대비매출채권
# 산업평균대비매출채권
# 총자산대비금융자산
# 총자산대비단기금융자산
# 금융자산수익률
# 단기금융자산수익률
# 총자산대비유가증권
# 유가증권수익률
# 산업평균대비유가증권
# 유형자산감가상각률
# 산업평균대비유형자산감가상각률
# 총자산대비유형자산
# 산업평균대비유형자산
# 무형자산상각률
# 산업평균대비무형자산상각률
# 총자산대비무형자산
# 개발비계상비율
# 산업평균대비무형자산
# 재고자산회전율
# 매출원가율
# 총자산대비재고
# 산업평균대비재고
# 유효이자율
# 단기유효이자율
# 총자산대비차입금
# 산업평균대비차입금
# 역마진여부
# 단기역마진여부
# 감사의견

# %% [markdown]
# ## 4.1. 하나의 컬럼에 대해서만 없애는 방법

# %%
def outliers_removal(feature,feature_name,dataset):
    
    # Identify 25th & 75th quartiles

    q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
    feat_iqr = q75 - q25    
    feat_cut_off = feat_iqr * 1.5
    feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off
    
    outliers = [x for x in feature if x < feat_lower or x > feat_upper]
    print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
    #print(feature_name + ' outliers:{}'.format(outliers))

    dataset = dataset.drop(dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index)
    print(len(dataset))
    
    print('-' * 65)
    
    return dataset

df_removed1 = outliers_removal(df['총자산대비무형자산'],'총자산대비무형자산',df)
    
# 이러면 맨 마지막 것만 떨어지므로 감사의견만 1이 제거됨. 병신임.
# Out:
# 총자산대비무형자산 Amount of outliers: 1775
# 11416
# -----------------------------------------------------------------

# %%
df_removed1
# Out:
#         총자산대비현금  산업평균대비현금    매출채권회전율    매출총이익률       대손률  총자산대비매출채권  \
# 1      0.053984 -0.010436   6.125292  0.218396  0.000000   0.122641
# 2      0.005949 -0.058471   0.000000  0.463296  0.000000   0.000000
# 10     0.080726  0.016307   5.330486  0.126241  0.000000   0.151961
# 11     0.018427 -0.045992   8.316436  0.119673  0.000000   0.060990
# 14     0.081340  0.016920   5.780349  0.550493 -0.006690   0.077725
# ...         ...       ...        ...       ...       ...        ...
# 25034  0.126028  0.061609  11.039697  0.177957  0.000000   0.105728
# 25035  0.011082 -0.053337  31.219595  0.383469  0.000000   0.022746
# 25036  0.021297 -0.043122   0.000000  0.592762  0.000000   0.000000
# 25038  0.098020  0.033600   3.343085  0.258193  0.068897   0.430191
# 25039  0.087534  0.023115   4.601281  0.135155  0.010284   0.175002
#
#        산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산   금융자산수익률  ...     매출원가율   총자산대비재고  \
# ...

# %%
df_removed1['감사의견'].value_counts()
# Out:
# 0    11244
# 1      172
# Name: 감사의견, dtype: int64

# %% [raw]
# 원래 값은 다음과 같음. 거의 200개에 가까운 target이 떨어져 나감.
# >* 0 :   12980
# >* 1 :   751

# %%
(12980-11354)/12980
# Out:
# 0.12526964560862866

# %%
(751- 574) /751
# 거의 2배 가깝게 떨어짐. 이거 괜찮은건가?
# 이게 어떠한 예측력을 갖는 것인가?
# Out:
# 0.23568575233022637

# %% [markdown]
# * 분포재확인

# %%
for j,i in enumerate(range(df_removed1.shape[1])):
    
    print('{0}. {1}:' .format(j,df_removed1.columns[i]))
    print("    1. Skewness: %f" % df_removed1.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df_removed1.iloc[:,i].kurt())
# Out:
# 0. 총자산대비현금:
#     1. Skewness: 6.734073
#     2. Kurtosis: 187.310643
#
# 1. 산업평균대비현금:
#     1. Skewness: 6.734073
#     2. Kurtosis: 187.310643
#
# 2. 매출채권회전율:
#     1. Skewness: 105.662008
#     2. Kurtosis: 11237.916341
#
# 3. 매출총이익률:
#     1. Skewness: -99.441528
#     2. Kurtosis: 10260.529880
#
# 4. 대손률:
#     1. Skewness: -5.666731
#     2. Kurtosis: 3634.262103
#
# 5. 총자산대비매출채권:
#     1. Skewness: 1.592969
#     2. Kurtosis: 4.280138
#
# 6. 산업평균대비매출채권:
#     1. Skewness: 1.592969
#     2. Kurtosis: 4.280138
#
# 7. 총자산대비금융자산:
#     1. Skewness: 2.125747
#     2. Kurtosis: 5.067723
#
# 8. 총자산대비단기금융자산:
#     1. Skewness: 2.824917
#     2. Kurtosis: 9.500385
#
# 9. 금융자산수익률:
#     1. Skewness: 92.825905
#     2. Kurtosis: 9054.080662
#
# 10. 단기금융자산수익률:
#     1. Skewness: 96.835673
#     2. Kurtosis: 9808.837035
#
# 11. 총자산대비유가증권:
#     1. Skewness: 4.527501
#     2. Kurtosis: 25.617443
#
# 12. 유가증권수익률:
#     1. Skewness: 77.617947
#     2. Kurtosis: 6231.532370
#
# ...

# %% [markdown]
# ## 4.2 모든 컬럼에 대해 없애는 방법

# %%
def outliers_removal(dataset):
    
    drop_index = set([])
    
    for col in dataset.columns[:-1]:
        
        feature = dataset[col]
        feature_name = col
        
        
        q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
        feat_iqr = q75 - q25    
        feat_cut_off = feat_iqr * 1.5
        feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off

        outliers = [x for x in feature if x < feat_lower or x > feat_upper]
        print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
        #print(feature_name + ' outliers:{}'.format(outliers))

        
        removal_index = dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index
        
        drop_index.update(list(removal_index))
        
        # k.update([3, 4, 5]) : 집합에 여러 값 추가시 사용
        
        print('제거 레코드 수: %d' %len(drop_index))

        print('-' * 65)
    
    dataset = dataset.drop(list(drop_index))    
    print('남은 레코드 수: %d' %len(dataset))

    return dataset
       
        
df_removed2 = outliers_removal(df)
# Out:
# 총자산대비현금 Amount of outliers: 752
# 제거 레코드 수: 752
# -----------------------------------------------------------------
# 산업평균대비현금 Amount of outliers: 752
# 제거 레코드 수: 752
# -----------------------------------------------------------------
# 매출채권회전율 Amount of outliers: 1210
# 제거 레코드 수: 1851
# -----------------------------------------------------------------
# 매출총이익률 Amount of outliers: 996
# 제거 레코드 수: 2568
# -----------------------------------------------------------------
# 대손률 Amount of outliers: 2819
# 제거 레코드 수: 4733
# -----------------------------------------------------------------
# 총자산대비매출채권 Amount of outliers: 464
# 제거 레코드 수: 5095
# -----------------------------------------------------------------
# 산업평균대비매출채권 Amount of outliers: 464
# 제거 레코드 수: 5095
# -----------------------------------------------------------------
# 총자산대비금융자산 Amount of outliers: 987
# 제거 레코드 수: 5695
# -----------------------------------------------------------------
# 총자산대비단기금융자산 Amount of outliers: 1433
# ...

# %%
df_removed2
# Out:
#         총자산대비현금  산업평균대비현금    매출채권회전율    매출총이익률       대손률  총자산대비매출채권  \
# 69     0.057527 -0.006892  11.120648  0.130644  0.000013   0.078933
# 77     0.194920  0.130501   5.355706  0.206814  0.003270   0.182796
# 102    0.115560  0.051141   3.441723  0.483012  0.021207   0.252571
# 148    0.069310  0.004890   4.786868  0.177958 -0.010570   0.125146
# 158    0.031705 -0.032715  10.381526  0.125374  0.014607   0.072471
# ...         ...       ...        ...       ...       ...        ...
# 24982  0.124285  0.059866  13.456649  0.414128  0.015588   0.051889
# 25023  0.000213 -0.064206  12.314562 -0.013060  0.000000   0.096225
# 25024  0.130330  0.065911   4.639587  0.096189  0.001482   0.316661
# 25026  0.164083  0.099663  11.649186  0.159212 -0.001298   0.246658
# 25032  0.012875 -0.051544   0.494141  0.163893 -0.000040   0.183730
#
#        산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산   금융자산수익률  ...     매출원가율   총자산대비재고  \
# ...

# %%
for j,i in enumerate(range(df_removed2.shape[1])):
    
    print('{0}. {1}:' .format(j,df_removed2.columns[i]))
    print("    1. Skewness: %f" % df_removed2.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df_removed2.iloc[:,i].kurt())
# Out:
# 0. 총자산대비현금:
#     1. Skewness: 1.317316
#     2. Kurtosis: 1.204680
#
# 1. 산업평균대비현금:
#     1. Skewness: 1.317316
#     2. Kurtosis: 1.204680
#
# 2. 매출채권회전율:
#     1. Skewness: 0.914021
#     2. Kurtosis: 0.811787
#
# 3. 매출총이익률:
#     1. Skewness: 0.715737
#     2. Kurtosis: 0.916542
#
# 4. 대손률:
#     1. Skewness: 0.977853
#     2. Kurtosis: 1.482895
#
# 5. 총자산대비매출채권:
#     1. Skewness: 0.558702
#     2. Kurtosis: -0.302975
#
# 6. 산업평균대비매출채권:
#     1. Skewness: 0.558702
#     2. Kurtosis: -0.302975
#
# 7. 총자산대비금융자산:
#     1. Skewness: 1.346512
#     2. Kurtosis: 1.707084
#
# 8. 총자산대비단기금융자산:
#     1. Skewness: 1.458501
#     2. Kurtosis: 1.297152
#
# 9. 금융자산수익률:
#     1. Skewness: 1.253497
#     2. Kurtosis: 1.063635
#
# 10. 단기금융자산수익률:
#     1. Skewness: 1.628067
#     2. Kurtosis: 2.564668
#
# 11. 총자산대비유가증권:
#     1. Skewness: 2.728673
#     2. Kurtosis: 6.954862
#
# 12. 유가증권수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 13. 산업평균대비유가증권:
#     1. Skewness: 0.000000
# ...

# %%
df_removed2['감사의견'].value_counts()

# ㅅㅂ 왜이렇게 줄었냐?
# Out:
# 0    2012
# 1      10
# Name: 감사의견, dtype: int64

# %% [markdown]
# * 이상치 제거 후 EDA

# %%
f, ax = plt.subplots(figsize=(30, 25))

mat = df_removed2.corr('spearman')
mask = np.triu(np.ones_like(mat, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(mat, mask=mask, cmap=cmap, vmax=1, center=0, annot = True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# 왜 개발비 계상비율은 아예 없어졌는지
# => 평균이 거의 0이므로 위에가 다 잘림.

# %% [markdown]
# * 순위재확인

# %%
mat['감사의견'].abs().sort_values(ascending = False)[1:11]
# Out:
# 산업평균대비현금       0.066151
# 총자산대비현금        0.066151
# 총자산대비금융자산      0.065168
# 대손률            0.058546
# 총자산대비단기금융자산    0.054748
# 총자산대비유가증권      0.051179
# 단기유효이자율        0.045957
# 단기역마진여부        0.045234
# 총자산대비매출채권      0.041077
# 산업평균대비매출채권     0.041077
# Name: 감사의견, dtype: float64

# %%
mat['감사의견'].sort_values(ascending = False)[1:6]
# Out:
# 단기역마진여부      0.045234
# 매출원가율        0.039930
# 산업평균대비차입금    0.037120
# 총자산대비차입금     0.037120
# 총자산대비유형자산    0.006703
# Name: 감사의견, dtype: float64

# %%
mat['감사의견'].sort_values(ascending = True)[:5]
# Out:
# 총자산대비현금       -0.066151
# 산업평균대비현금      -0.066151
# 총자산대비금융자산     -0.065168
# 대손률           -0.058546
# 총자산대비단기금융자산   -0.054748
# Name: 감사의견, dtype: float64

# %%
draw_boxplot(df_removed2, 6, math.ceil(df_removed2.shape[1]/6))

# %%
draw_distplot(df_removed2, 6, math.ceil(df_removed2.shape[1]/6))

# %% [markdown]
# 4.3. 상하위 1%에 대해서만 없애는방법

# %% [markdown]
# * 이 방법 어디 정리해 놓은 것 같은데 찾아봐야.

# %% [markdown]
# # 5. 타겟 데이터 Oversampling

# %% [markdown]
# 아래 모형학습에 포함.

# %% [markdown]
# 이거 안했더니 전부 yes 로 찍고 점수 받더라... 지금 큰일난거

# %% [markdown]
# # 6. 모형학습

# %% [markdown]
# ## 6.1. 하나만 없앤 데이터 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from keras import models
from keras import layers

# %% [markdown]
# * SMOTE 를 이용하여 오버샘플링

# %%
from imblearn.over_sampling import SMOTE

# %%
X_1=df_removed1.drop(labels=['감사의견'], axis=1)
y_1=df_removed1['감사의견']

# %%
oversample = SMOTE()
X_1,y_1=oversample.fit_resample(X_1,y_1)

# %%
X_1.shape, y_1.shape 
# df_removed1.shape : (11928, 34)
# X.shape[0]/df_removed1.shape[0] : 1.903755868544601
# Out:
# ((22488, 33), (22488,))

# %%
plt.rcParams["font.size"]=14

sns.countplot(x=y_1)
print('X.shape, y.shape : ',X_1.shape, y_1.shape)
plt.xlabel('감사의견')
plt.title('Audit Opinion Distribution')
plt.show()
# Out:
# X.shape, y.shape :  (22488, 33) (22488,)

# %%
X_1.shape
# Out:
# (22488, 33)

# %%
y_1.value_counts(0)
# Out:
# 0    11244
# 1    11244
# Name: 감사의견, dtype: int64

# %%
len(X_1)/len(df)
# Out:
# 1.7047987264043667

# %% [markdown]
# * 학습에 사용할 피쳐 선택

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest

# %% [markdown]
# StandardScaler
# * Select 30 independent variables out of 96 variables.
# * 이거 Stratified Cross Validation Splitting 아니면 필요 없는데
# * 애초에 Stratified Cross Validation Splitting 이 무엇인가, 필요한가?

# %%
# feature_selection=SelectKBest(f_classif,k=20).fit(X,y)
# selected_features=X.columns[feature_selection.get_support()]

# K Best 는 하지 않음

# %%
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_1, y_1,test_size=0.2)

# %%
for i in [X_train_1, X_test_1, y_train_1, y_test_1]:
    print(i.shape)
# Out:
# (17990, 33)
# (4498, 33)
# (17990,)
# (4498,)

# %% [markdown]
# ### 6.1.1. 앙상블 보팅으로 예측

# %%
dt_clf = DecisionTreeClassifier()
knn_clf = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier( estimators=[('DT',dt_clf),('KNN',knn_clf)] , voting='soft' )

# %%
vo_clf.fit(X_train_1 , y_train_1)
# Out:
# VotingClassifier(estimators=[('DT', DecisionTreeClassifier()),
#                              ('KNN', KNeighborsClassifier(n_neighbors=8))],
#                  voting='soft')

# %%
pred_vo_1 = vo_clf.predict(X_test_1)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test_1 , pred_vo_1)))

# 정확도가 올라갔다... 왜?
# 아 개오바야....
# Out:
# Voting 분류기 정확도: 0.9673

# %%
print(classification_report(y_test_1,pred_vo_1,\
         target_names=['0','1']))
print(confusion_matrix(y_test_1,pred_vo_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      2241
#            1       0.97      0.96      0.97      2257
#
#     accuracy                           0.97      4498
#    macro avg       0.97      0.97      0.97      4498
# weighted avg       0.97      0.97      0.97      4498
#
# [[2182   59]
#  [  88 2169]]

# %% [markdown]
# * 개별모델 예측 평가

# %%
classifiers = [dt_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train_1 , y_train_1)
    pred = classifier.predict(X_test_1)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test_1 , pred)))
    
    print(classification_report(y_test_1,pred,target_names=['0','1']))
    print(confusion_matrix(y_test_1,pred),'\n')
    
# 왜 정확도가 같다고 나오지???
# 하나로 찍으니까 그렇게 나오지.

# 참고로, 로지스틱은 정규화 하고 넣어야 한다.
# Out:
# DecisionTreeClassifier 정확도: 0.9473
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95      2241
#            1       0.93      0.96      0.95      2257
#
#     accuracy                           0.95      4498
#    macro avg       0.95      0.95      0.95      4498
# weighted avg       0.95      0.95      0.95      4498
#
# [[2086  155]
#  [  82 2175]]
#
# KNeighborsClassifier 정확도: 0.9257
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92      2241
#            1       0.90      0.96      0.93      2257
#
#     accuracy                           0.93      4498
#    macro avg       0.93      0.93      0.93      4498
# weighted avg       0.93      0.93      0.93      4498
#
# [[1993  248]
#  [  86 2171]]

# %% [markdown]
# ### 6.1.2. 랜덤포레스트로 예측

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train_1 , y_train_1)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf_1 = rf_clf.predict(X_test_1)
accuracy = accuracy_score(y_test_1 , pred_rf_1)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9842

# %%
ftr_importances = pd.Series(rf_clf.feature_importances_,index=df_removed1.columns[0:-1])

ftr_importances.sort_values(ascending = False).to_frame()
# Out:
#                         0
# 유효이자율            0.116237
# 매출총이익률           0.106451
# 매출원가율            0.090216
# 역마진여부            0.059885
# 산업평균대비차입금        0.051177
# 총자산대비차입금         0.051171
# 대손률              0.041484
# 재고자산회전율          0.039666
# 산업평균대비유형자산감가상각률  0.035463
# 매출채권회전율          0.035275
# 유형자산감가상각률        0.034722
# 산업평균대비현금         0.022366
# 총자산대비현금          0.022264
# 총자산대비무형자산        0.021943
# 총자산대비단기금융자산      0.021031
# 단기유효이자율          0.020874
# 산업평균대비재고         0.020746
# 총자산대비재고          0.019015
# 총자산대비금융자산        0.017344
# 단기역마진여부          0.016808
# 금융자산수익률          0.016754
# 단기금융자산수익률        0.015727
# 산업평균대비매출채권       0.014978
# 총자산대비매출채권        0.014825
# 산업평균대비유형자산       0.014067
# 산업평균대비무형자산상각률    0.013803
# 총자산대비유가증권        0.013776
# 총자산대비유형자산        0.013641
# 무형자산상각률          0.013299
# 산업평균대비무형자산       0.006558
# 개발비계상비율          0.006413
# 산업평균대비유가증권       0.006188
# 유가증권수익률          0.005832

# %%
ftr_importances_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_importances_top20.values , y = ftr_importances_top20.index)
plt.show()

# %%
print(classification_report(y_test_1,pred_rf_1,\
         target_names=['0','1']))
print(confusion_matrix(y_test_1,pred_rf_1))

# 랜덤포레스트는 나쁘지 않다.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      2241
#            1       0.98      0.99      0.98      2257
#
#     accuracy                           0.98      4498
#    macro avg       0.98      0.98      0.98      4498
# weighted avg       0.98      0.98      0.98      4498
#
# [[2191   50]
#  [  21 2236]]

# %% [markdown]
# ### 6.1.3. 로지스틱회귀분석 예측

# %% [markdown]
# * 정규화

# %%
scaler=StandardScaler()
X_scaled_1=scaler.fit_transform(X_1)

# %%
X_train_scaled_1, X_test_scaled_1, y_train_scaled_1, y_test_scaled_1 = train_test_split(X_scaled_1, y_1, test_size=0.2)

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train_scaled_1,y_train_scaled_1)
# Out:
# LogisticRegression()

# %% [markdown]
# * Metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
pred_lr_1 = lr_clf.predict(X_test_scaled_1)
accuracy = accuracy_score(y_test_scaled_1 , pred_lr_1)
print('로지스틱 회귀분석 정확도: {0:.4f}'.format(accuracy))
# Out:
# 로지스틱 회귀분석 정확도: 0.7350

# %%
print(classification_report(y_test_scaled_1,pred_lr_1))
print(confusion_matrix(y_test_scaled_1,pred_lr_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.79      0.75      2235
#            1       0.77      0.68      0.72      2263
#
#     accuracy                           0.73      4498
#    macro avg       0.74      0.74      0.73      4498
# weighted avg       0.74      0.73      0.73      4498
#
# [[1767  468]
#  [ 724 1539]]

# %% [markdown]
# ### 6.1.4 서포트벡터머신 예측

# %% [markdown]
# * 서포트벡터머신 : 패턴 인식, 자료 분석을 위한 지도 학습 모델이며, 주로 분류와 회귀 분석을 위해 사용

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train_scaled_1, y_train_scaled_1)
# Out:
# SVC()

# %%
model.score(X_test_scaled_1,y_test_scaled_1)

# 이상치 제거 전후가 왜 이렇게 유의적으로 차이가 나는거지?
# Out:
# 0.7947976878612717

# %%
pred_svc_1=model.predict(X_test_scaled_1)

# %%
print(classification_report(y_test_scaled_1, pred_svc_1))
print(confusion_matrix(y_test_scaled_1,pred_svc_1))

# 개수 보면 오류는 아니다.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79      2235
#            1       0.80      0.80      0.80      2263
#
#     accuracy                           0.79      4498
#    macro avg       0.79      0.79      0.79      4498
# weighted avg       0.79      0.79      0.79      4498
#
# [[1774  461]
#  [ 462 1801]]

# %% [markdown]
# ### 6.1.5. 인공신경망으로 예측

# %% [markdown]
# * Minmax scaling

# %%
MinMax_scaler = preprocessing.MinMaxScaler()
X_minmax_scaled_1=MinMax_scaler.fit_transform(X_1)

# %%
X_train_minmax_scaled_1, X_test_minmax_scaled_1, y_train_minmax_scaled_1, y_test_minmax_scaled_1 = train_test_split(X_minmax_scaled_1, 
                                                                                                                    y_1, test_size=0.2)

# %%
X_train_minmax_scaled_1.shape, X_test_minmax_scaled_1.shape, y_train_minmax_scaled_1.shape, y_test_minmax_scaled_1.shape
# Out:
# ((17990, 33), (4498, 33), (17990,), (4498,))

# %% [markdown]
# * 모형생성 및 학습

# %%
model=models.Sequential()
model.add(layers.Dense(4, activation='relu',input_dim=X_train_minmax_scaled_1.shape[1]))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 4)                 136
#
#  dense_1 (Dense)             (None, 4)                 20
#
#  dense_2 (Dense)             (None, 1)                 5
#
# ...
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train_minmax_scaled_1,y_train_minmax_scaled_1,
                 epochs=200,batch_size=128,
                 validation_split=0.3) # class_weight={0:1,1:1}) # class_weight={0:0.0506,1:1} 

# smote 했으므로 가중치 1:1 로 학습.
# 모형의 문제는 아니다....
# Out:
# Epoch 1/200
# 99/99 [==============================] - 3s 9ms/step - loss: 0.6930 - accuracy: 0.5289 - val_loss: 0.6879 - val_accuracy: 0.5627
# Epoch 2/200
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6863 - accuracy: 0.5616 - val_loss: 0.6845 - val_accuracy: 0.5674
# Epoch 3/200
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6830 - accuracy: 0.5687 - val_loss: 0.6816 - val_accuracy: 0.5714
# Epoch 4/200
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6798 - accuracy: 0.5762 - val_loss: 0.6787 - val_accuracy: 0.5800
# Epoch 5/200
# 99/99 [==============================] - 0s 4ms/step - loss: 0.6765 - accuracy: 0.5829 - val_loss: 0.6753 - val_accuracy: 0.5868
# Epoch 6/200
# 99/99 [==============================] - 0s 5ms/step - loss: 0.6726 - accuracy: 0.5933 - val_loss: 0.6721 - val_accuracy: 0.5896
# Epoch 7/200
# ...

# %%
predicted_result=model.predict(X_test_minmax_scaled_1)
predicted_result.shape
# Out:
# 141/141 [==============================] - 1s 2ms/step
# (4498, 1)

# %%
pred_mlp_1=pd.Series([1 if predicted_result[i]> 0.5 \
         else 0 for i in range(0,predicted_result.shape[0])])

# %%
accuracy = accuracy_score(y_test_minmax_scaled_1 , pred_mlp_1)
print('인공신경망 정확도: {0:.4f}'.format(accuracy))
# Out:
# 인공신경망 정확도: 0.7430

# %%
print(classification_report(y_test_minmax_scaled_1,pred_mlp_1,\
         target_names=['0','1']))
print(confusion_matrix(y_test_minmax_scaled_1,pred_mlp_1))

# 정확도만 높고 나머지는 병신인데? 이유가 뭐냐
# 해당 피쳐들로는 맞는것을 고르기는 쉬운데 아닌 것을 고르는게 거의 불가능.

# 아니 왜 하나로 쳐 미는데...
# => 점수를 이런 식으로 주면 19:1 의 비율로 존재하므로 한 값으로 밀어도 95점이 나오는 것. 그래서 이렇게...

# no yes 가 맞음... 지금 0으로 예측한 것이 전부인데 이렇게 도출됨.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73      2248
#            1       0.73      0.78      0.75      2250
#
#     accuracy                           0.74      4498
#    macro avg       0.74      0.74      0.74      4498
# weighted avg       0.74      0.74      0.74      4498
#
# [[1591  657]
#  [ 499 1751]]

# %%
history_dict=history.history
history_dict.keys()

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)

# %%
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot(epochs,acc,'bo',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.2 전부 없앤 데이터 학습

# %% [markdown]
# * SMOTE 를 이용하여 오버샘플링

# %%
X_2=df_removed2.drop(labels=['감사의견'], axis=1)
y_2=df_removed2['감사의견']

# %%
oversample = SMOTE()
X_2,y_2=oversample.fit_resample(X_2,y_2)

# %%
# X.shape, y.shape : ((4090, 33), (4090,))
# df_removed2.shape : (2091, 34)
# X.shape[0]/df_removed2.shape[0] : 1.9560019129603061

# %%
sns.countplot(x=y_2)
# Out:
# <AxesSubplot:xlabel='감사의견', ylabel='count'>

# %%
X_2.shape, y_2.shape
# Out:
# ((4024, 33), (4024,))

# %% [markdown]
# * 학습에 사용할 피쳐 선택

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest

# %%
# feature_selection=SelectKBest(f_classif,k=20).fit(X,y)
# selected_features=X.columns[feature_selection.get_support()]

# K Best 안함

# %%
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_2, y_2,test_size=0.2)

# %%
for i in [X_train_2, X_test_2, y_train_2, y_test_2]:
    print(i.shape)
# Out:
# (3219, 33)
# (805, 33)
# (3219,)
# (805,)

# %% [markdown]
# ### 6.2.1. 앙상블 보팅으로 예측

# %%
dt_clf = DecisionTreeClassifier()
knn_clf = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier( estimators=[('DT',dt_clf),('KNN',knn_clf)] , voting='soft' )

# %%
vo_clf.fit(X_train_2 , y_train_2)
# Out:
# VotingClassifier(estimators=[('DT', DecisionTreeClassifier()),
#                              ('KNN', KNeighborsClassifier(n_neighbors=8))],
#                  voting='soft')

# %%
pred_vo_2 = vo_clf.predict(X_test_2)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test_2 , pred_vo_2)))
# Out:
# Voting 분류기 정확도: 0.9888

# %%
print(classification_report(y_test_2,pred_vo_2,\
         target_names=['0','1']))
print(confusion_matrix(y_test_2,pred_vo_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       387
#            1       0.98      1.00      0.99       418
#
#     accuracy                           0.99       805
#    macro avg       0.99      0.99      0.99       805
# weighted avg       0.99      0.99      0.99       805
#
# [[380   7]
#  [  2 416]]

# %% [markdown]
# * 개별모델 예측 평가

# %%
classifiers = [dt_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train_2 , y_train_2)
    pred = classifier.predict(X_test_2)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test_2 , pred)))
    
    print(classification_report(y_test_2,pred,target_names=['0','1']))
    print(confusion_matrix(y_test_2,pred),'\n')
    
# 왜 정확도가 같다고 나오지???
# 하나로 찍으니까 그렇게 나오지.

# 참고로, 로지스틱은 정규화 하고 넣어야 한다.
# Out:
# DecisionTreeClassifier 정확도: 0.9851
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       387
#            1       0.98      1.00      0.99       418
#
#     accuracy                           0.99       805
#    macro avg       0.99      0.98      0.99       805
# weighted avg       0.99      0.99      0.99       805
#
# [[377  10]
#  [  2 416]]
#
# KNeighborsClassifier 정확도: 0.9068
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90       387
#            1       0.88      0.95      0.91       418
#
#     accuracy                           0.91       805
#    macro avg       0.91      0.91      0.91       805
# weighted avg       0.91      0.91      0.91       805
#
# [[333  54]
#  [ 21 397]]

# %% [markdown]
# ### 6.2.2. 랜덤포레스트로 예측

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train_2 , y_train_2)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf_2 = rf_clf.predict(X_test_2)
accuracy = accuracy_score(y_test_2 , pred_rf_2)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9975

# %%
ftr_importances = pd.Series(rf_clf.feature_importances_,index=df_removed2.columns[0:-1])

top_ftr_importances = ftr_importances.sort_values(ascending = False).to_frame()
top_ftr_importances
# Out:
#                         0
# 총자산대비단기금융자산      0.138193
# 총자산대비현금          0.106553
# 산업평균대비현금         0.084550
# 총자산대비유가증권        0.072817
# 대손률              0.058958
# 총자산대비무형자산        0.058191
# 총자산대비금융자산        0.057796
# 단기역마진여부          0.054121
# 매출채권회전율          0.051791
# 총자산대비매출채권        0.048476
# 단기유효이자율          0.044292
# 산업평균대비매출채권       0.043452
# 총자산대비재고          0.015163
# 매출원가율            0.014471
# 산업평균대비차입금        0.014397
# 산업평균대비재고         0.013351
# 산업평균대비유형자산감가상각률  0.013120
# 유효이자율            0.012486
# 유형자산감가상각률        0.011922
# 금융자산수익률          0.011818
# 매출총이익률           0.010796
# 총자산대비차입금         0.010725
# 단기금융자산수익률        0.010705
# 재고자산회전율          0.010228
# 총자산대비유형자산        0.008000
# 산업평균대비유형자산       0.007562
# 역마진여부            0.006879
# 무형자산상각률          0.004879
# 산업평균대비무형자산상각률    0.004308
# 유가증권수익률          0.000000
# 산업평균대비유가증권       0.000000
# 개발비계상비율          0.000000
# 산업평균대비무형자산       0.000000

# %%
top_index = top_ftr_importances.index[:6]
top_index
# Out:
# Index(['총자산대비단기금융자산', '총자산대비현금', '산업평균대비현금', '총자산대비유가증권', '대손률', '총자산대비무형자산'], dtype='object')

# %%
import math

plt.rcParams["font.size"]=14

def draw_boxplot(dataset, columns, horizental_number, vertical_number):
        
    for j in range(vertical_number):
        cols = columns[j*horizental_number:(j+1)*horizental_number]

        n=0
        f, axes = plt.subplots(ncols=horizental_number, figsize=(12,8/horizental_number))

        for i in cols:
            sns.boxplot(x= '감사의견', y= i , data=dataset, ax=axes[n])
            axes[n].set_title(i, fontsize=16)
            axes[n].set_ylabel("")
            
            n=n+1
        plt.show()

horizental_number = 3
draw_boxplot(df_removed2, top_index, horizental_number, math.ceil(len(top_index)/horizental_number))

# %%
plt.rcParams["font.size"]=20

ftr_importances_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(16,12))
plt.title('Feature importances')
sns.barplot(x=ftr_importances_top20.values , y = ftr_importances_top20.index)
plt.show()

# %%
print(classification_report(y_test_2,pred_rf_2,\
         target_names=['0','1']))
print(confusion_matrix(y_test_2,pred_rf_2))

# 랜덤포레스트는 나쁘지 않다.
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       387
#            1       1.00      1.00      1.00       418
#
#     accuracy                           1.00       805
#    macro avg       1.00      1.00      1.00       805
# weighted avg       1.00      1.00      1.00       805
#
# [[385   2]
#  [  0 418]]

# %% [markdown]
# ### 6.2.3. 로지스틱회귀분석 예측

# %% [markdown]
# * 정규화

# %%
scaler=StandardScaler()
X_scaled_2=scaler.fit_transform(X_2)

# %%
X_train_scaled_2, X_test_scaled_2, y_train_scaled_2, y_test_scaled_2 = train_test_split(X_scaled_2, y_2, test_size=0.2)

# %%
X_train_scaled_2.shape, X_test_scaled_2.shape, y_train_scaled_2.shape, y_test_scaled_2.shape
# Out:
# ((3219, 33), (805, 33), (3219,), (805,))

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train_scaled_2,y_train_scaled_2)
# Out:
# LogisticRegression()

# %% [markdown]
# * Metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
pred_lr_2 = lr_clf.predict(X_test_scaled_2)
accuracy = accuracy_score(y_test_scaled_2 , pred_lr_2)
print('로지스틱 회귀분석 정확도: {0:.4f}'.format(accuracy))
# Out:
# 로지스틱 회귀분석 정확도: 0.9516

# %%
print(classification_report(y_test_scaled_2,pred_lr_2))
print(confusion_matrix(y_test_scaled_2,pred_lr_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95       421
#            1       0.91      1.00      0.95       384
#
#     accuracy                           0.95       805
#    macro avg       0.95      0.95      0.95       805
# weighted avg       0.96      0.95      0.95       805
#
# [[382  39]
#  [  0 384]]

# %% [markdown]
# ### 6.2.4 서포트벡터머신 예측

# %% [markdown]
# * 서포트벡터머신 : 패턴 인식, 자료 분석을 위한 지도 학습 모델이며, 주로 분류와 회귀 분석을 위해 사용

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train_scaled_2, y_train_scaled_2)
# Out:
# SVC()

# %%
pred_svc_2=model.predict(X_test_scaled_2)
accuracy = accuracy_score(y_test_scaled_2 , pred_svc_2)
print('SVM 정확도: {0:.4f}'.format(accuracy))
# Out:
# SVM 정확도: 1.0000

# %%
print(classification_report(y_test_scaled_2, pred_svc_2))
print(confusion_matrix(y_test_scaled_2,pred_svc_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       421
#            1       1.00      1.00      1.00       384
#
#     accuracy                           1.00       805
#    macro avg       1.00      1.00      1.00       805
# weighted avg       1.00      1.00      1.00       805
#
# [[421   0]
#  [  0 384]]

# %% [markdown]
# ### 6.2.5. 인공신경망으로 예측

# %% [markdown]
# * Minmax scaling

# %%
MinMax_scaler = preprocessing.MinMaxScaler()
X_minmax_scaled_2=MinMax_scaler.fit_transform(X_2)

# %%
X_train_minmax_scaled_2, X_test_minmax_scaled_2, y_train_minmax_scaled_2, y_test_minmax_scaled_2 = train_test_split(X_minmax_scaled_2, 
                                                                                                                    y_2, test_size=0.2)

# %%
X_train_minmax_scaled_2.shape, X_test_minmax_scaled_2.shape, y_train_minmax_scaled_2.shape, y_test_minmax_scaled_2.shape
# Out:
# ((3219, 33), (805, 33), (3219,), (805,))

# %% [markdown]
# * 모형생성 및 학습

# %%
model=models.Sequential()
model.add(layers.Dense(4, activation='relu',input_dim=X_train_minmax_scaled_2.shape[1]))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 4)                 136
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 1)                 5
#
# ...
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train_minmax_scaled_2,y_train_minmax_scaled_2,
                 epochs=200,batch_size=128,
                 validation_split=0.3, class_weight={0:1,1:1}) # class_weight={0:0.0506,1:1} 

# smote 했으므로 가중치 1:1 로 학습.
# Out:
# Epoch 1/200
# 18/18 [==============================] - 2s 33ms/step - loss: 0.6888 - accuracy: 0.4119 - val_loss: 0.6810 - val_accuracy: 0.4161
# Epoch 2/200
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6693 - accuracy: 0.5171 - val_loss: 0.6656 - val_accuracy: 0.5880
# Epoch 3/200
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6538 - accuracy: 0.6378 - val_loss: 0.6533 - val_accuracy: 0.6149
# Epoch 4/200
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6408 - accuracy: 0.6529 - val_loss: 0.6409 - val_accuracy: 0.6294
# Epoch 5/200
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6273 - accuracy: 0.6618 - val_loss: 0.6276 - val_accuracy: 0.6418
# Epoch 6/200
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6136 - accuracy: 0.6755 - val_loss: 0.6135 - val_accuracy: 0.6718
# Epoch 7/200
# ...

# %%
predicted_result=model.predict(X_test_minmax_scaled_2)
predicted_result.shape
# Out:
# 26/26 [==============================] - 0s 2ms/step
# (805, 1)

# %%
pred_mlp_2=pd.Series([1 if predicted_result[i]> 0.5 \
         else 0 for i in range(0,predicted_result.shape[0])])

# %%
accuracy = accuracy_score(y_test_minmax_scaled_2 , pred_mlp_2)
print('인공신경망 정확도: {0:.4f}'.format(accuracy))
# Out:
# 인공신경망 정확도: 0.9950

# %%
print(classification_report(y_test_minmax_scaled_2,pred_mlp_2,\
         target_names=['0','1']))
print(confusion_matrix(y_test_minmax_scaled_2,pred_mlp_2))

# 정확도만 높고 나머지는 병신인데? 이유가 뭐냐
# 해당 피쳐들로는 맞는것을 고르기는 쉬운데 아닌 것을 고르는게 거의 불가능.

# 아니 왜 하나로 쳐 미는데...
# => 점수를 이런 식으로 주면 19:1 의 비율로 존재하므로 한 값으로 밀어도 95점이 나오는 것. 그래서 이렇게...
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       389
#            1       0.99      1.00      1.00       416
#
#     accuracy                           1.00       805
#    macro avg       1.00      0.99      1.00       805
# weighted avg       1.00      1.00      1.00       805
#
# [[385   4]
#  [  0 416]]

# %%
history_dict=history.history
history_dict.keys()

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)

# %%
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot(epochs,acc,'bo',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 추가할 내용
#
# 1. AUC 그리기
# 2. confusion matrix 그리기

# %% [markdown]
# # 7. 결과비교

# %% [markdown]
# ## 7.1 한 값만 제거

# %% [markdown]
# ### 7.1.1 ROC 곡선

# %%
pred_vo_1.shape
# Out:
# (4498,)

# %%
y_test_1.shape
# Out:
# (4498,)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import recall_score, f1_score,  precision_score
from sklearn.metrics import precision_recall_curve, average_precision_score

# %%
plt.rcParams["font.size"]=20

vo_fpr, vo_tpr, vo_thresold = roc_curve(y_test_1, pred_vo_1)
rf_fpr, rf_tpr, rf_threshold = roc_curve(y_test_1, pred_rf_1)
lr_fpr, lr_tpr, lr_thresold = roc_curve(y_test_scaled_1, pred_lr_1)
svc_fpr, svc_tpr, svc_thresold = roc_curve(y_test_scaled_1, pred_svc_1)
mlp_fpr, mlp_tpr, mlp_thresold = roc_curve(y_test_minmax_scaled_1, pred_mlp_1)


def graph_roc_curve_multiple(vo_fpr, vo_tpr, rf_fpr, rf_tpr, lr_fpr, lr_tpr, svc_fpr, svc_tpr, mlp_fpr, mlp_tpr):
    plt.figure(figsize=(20,8))
    plt.title('ROC Curve', fontsize=20)
    
    plt.plot(vo_fpr, vo_tpr, label='Voting Classifier Score: {:.4f}'.format(roc_auc_score(y_test_1, pred_vo_1)))
    plt.plot(rf_fpr, rf_tpr, label='Random Forest Classifier Score: {:.4f}'.format(roc_auc_score(y_test_1, pred_rf_1)))
    plt.plot(lr_fpr, lr_tpr, label='Logistic Regression Classifier Score: {:.4f}'.format(roc_auc_score(y_test_scaled_1, pred_lr_1)))
    plt.plot(svc_fpr, svc_tpr, label='SVM Classifier Score: {:.4f}'.format(roc_auc_score(y_test_scaled_1, pred_svc_1)))
    plt.plot(mlp_fpr, mlp_tpr, label='MLP Classifier Score: {:.4f}'.format(roc_auc_score(y_test_minmax_scaled_1, pred_mlp_1)))

    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([-0.01, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=20)
    plt.ylabel('True Positive Rate', fontsize=20)
    plt.annotate('Minimum ROC Score of 50% \n (This is the minimum score to get)', xy=(0.5, 0.5), xytext=(0.6, 0.3),
                arrowprops=dict(facecolor='#6E726D', shrink=0.05),
                )
    plt.legend(fontsize=14)
    
graph_roc_curve_multiple(vo_fpr, vo_tpr, rf_fpr, rf_tpr, lr_fpr, lr_tpr, svc_fpr, svc_tpr, mlp_fpr, mlp_tpr)
plt.show()

# %% [markdown]
# ### 7.1.2 confusion matrix 시각화

# %%
# Plotting confusion matrix for each classifier

conf_mx0 = confusion_matrix(y_test_1,pred_vo_1)
conf_mx1 = confusion_matrix(y_test_1,pred_rf_1)
conf_mx2 = confusion_matrix(y_test_scaled_1,pred_lr_1)
conf_mx3 = confusion_matrix(y_test_scaled_1,pred_svc_1)
conf_mx4 = confusion_matrix(y_test_minmax_scaled_1,pred_mlp_1)


heat_cm0 = pd.DataFrame(conf_mx0, columns=np.unique(y_test_1), index = np.unique(y_test_1))
heat_cm0.index.name = 'Actual'
heat_cm0.columns.name = 'Predicted'

heat_cm1 = pd.DataFrame(conf_mx1, columns=np.unique(y_test_1), index = np.unique(y_test_1))
heat_cm1.index.name = 'Actual'
heat_cm1.columns.name = 'Predicted'

heat_cm2 = pd.DataFrame(conf_mx2, columns=np.unique(y_test_scaled_1), index = np.unique(y_test_scaled_1))
heat_cm2.index.name = 'Actual'
heat_cm2.columns.name = 'Predicted'

heat_cm3 = pd.DataFrame(conf_mx3, columns=np.unique(y_test_scaled_1), index = np.unique(y_test_scaled_1))
heat_cm3.index.name = 'Actual'
heat_cm3.columns.name = 'Predicted'

heat_cm4 = pd.DataFrame(conf_mx4, columns=np.unique(y_test_minmax_scaled_1), index = np.unique(y_test_minmax_scaled_1))
heat_cm4.index.name = 'Actual'
heat_cm4.columns.name = 'Predicted'

f, ax = plt.subplots(1, 5, figsize=(25,8))
f.subplots_adjust(left=None, bottom=None, right= 2, top=None, wspace=None, hspace= None)

sns.heatmap(heat_cm0, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[0])
ax[0].set_title('Voting Classifier\n', fontsize = 50)
sns.heatmap(heat_cm1, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[1])
ax[1].set_title('Random Forest Classifier\n', fontsize = 50)
sns.heatmap(heat_cm2, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[2])
ax[2].set_title('Logistic Regression Classifier\n', fontsize = 50)
sns.heatmap(heat_cm3, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[3])
ax[3].set_title('SVM Classifier\n', fontsize = 50)
sns.heatmap(heat_cm4, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[4])
ax[4].set_title('MLP Classifier\n', fontsize = 50)

plt.show()

# %% [markdown]
# ## 7.2 모든 값 제거

# %% [markdown]
# ### 7.2.1 ROC 곡선

# %%
pred_vo_2.shape
# Out:
# (805,)

# %%
y_test_2.shape
# Out:
# (805,)

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import recall_score, f1_score,  precision_score
from sklearn.metrics import precision_recall_curve, average_precision_score

# %%
plt.rcParams["font.size"]=20

vo_fpr, vo_tpr, vo_thresold = roc_curve(y_test_2, pred_vo_2)
rf_fpr, rf_tpr, rf_threshold = roc_curve(y_test_2, pred_rf_2)
lr_fpr, lr_tpr, lr_thresold = roc_curve(y_test_scaled_2, pred_lr_2)
svc_fpr, svc_tpr, svc_thresold = roc_curve(y_test_scaled_2, pred_svc_2)
mlp_fpr, mlp_tpr, mlp_thresold = roc_curve(y_test_minmax_scaled_2, pred_mlp_2)


def graph_roc_curve_multiple(vo_fpr, vo_tpr, rf_fpr, rf_tpr, lr_fpr, lr_tpr, svc_fpr, svc_tpr, mlp_fpr, mlp_tpr):
    plt.figure(figsize=(20,8))
    plt.title('ROC Curve', fontsize=20)
    
    plt.plot(vo_fpr, vo_tpr, label='Voting Classifier Score: {:.4f}'.format(roc_auc_score(y_test_2, pred_vo_2)))
    plt.plot(rf_fpr, rf_tpr, label='Random Forest Classifier Score: {:.4f}'.format(roc_auc_score(y_test_2, pred_rf_2)))
    plt.plot(lr_fpr, lr_tpr, label='Logistic Regression Classifier Score: {:.4f}'.format(roc_auc_score(y_test_scaled_2, pred_lr_2)))
    plt.plot(svc_fpr, svc_tpr, label='SVM Classifier Score: {:.4f}'.format(roc_auc_score(y_test_scaled_2, pred_svc_2)))
    plt.plot(mlp_fpr, mlp_tpr, label='MLP Classifier Score: {:.4f}'.format(roc_auc_score(y_test_minmax_scaled_2, pred_mlp_2)))

    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([-0.01, 1, 0, 1])
    plt.xlabel('False Positive Rate', fontsize=20)
    plt.ylabel('True Positive Rate', fontsize=20)
    plt.annotate('Minimum ROC Score of 50% \n (This is the minimum score to get)', xy=(0.5, 0.5), xytext=(0.6, 0.3),
                arrowprops=dict(facecolor='#6E726D', shrink=0.05),
                )
    plt.legend(fontsize=14)
    
graph_roc_curve_multiple(vo_fpr, vo_tpr, rf_fpr, rf_tpr, lr_fpr, lr_tpr, svc_fpr, svc_tpr, mlp_fpr, mlp_tpr)
plt.show()

# 그래프가 망한 이유 => 정규화 한 y_test값을 써서 이렇게 됨.??????
# 그냥 아래서 그려야 할 것 같은데?

# %% [markdown]
# ### 7.2.2 confusion matrix 시각화

# %%
###### Plotting confusion matrix for each classifier

conf_mx0 = confusion_matrix(y_test_2,pred_vo_2)
conf_mx1 = confusion_matrix(y_test_2,pred_rf_2)
conf_mx2 = confusion_matrix(y_test_scaled_2,pred_lr_2)
conf_mx3 = confusion_matrix(y_test_scaled_2,pred_svc_2)
conf_mx4 = confusion_matrix(y_test_minmax_scaled_2,pred_mlp_2)


heat_cm0 = pd.DataFrame(conf_mx0, columns=np.unique(y_test_2), index = np.unique(y_test_2))
heat_cm0.index.name = 'Actual'
heat_cm0.columns.name = 'Predicted'

heat_cm1 = pd.DataFrame(conf_mx1, columns=np.unique(y_test_2), index = np.unique(y_test_2))
heat_cm1.index.name = 'Actual'
heat_cm1.columns.name = 'Predicted'

heat_cm2 = pd.DataFrame(conf_mx2, columns=np.unique(y_test_scaled_2), index = np.unique(y_test_scaled_2))
heat_cm2.index.name = 'Actual'
heat_cm2.columns.name = 'Predicted'

heat_cm3 = pd.DataFrame(conf_mx3, columns=np.unique(y_test_scaled_2), index = np.unique(y_test_scaled_2))
heat_cm3.index.name = 'Actual'
heat_cm3.columns.name = 'Predicted'

heat_cm4 = pd.DataFrame(conf_mx4, columns=np.unique(y_test_minmax_scaled_2), index = np.unique(y_test_minmax_scaled_2))
heat_cm4.index.name = 'Actual'
heat_cm4.columns.name = 'Predicted'

f, ax = plt.subplots(1, 5, figsize=(25,8))
f.subplots_adjust(left=None, bottom=None, right= 2, top=None, wspace=None, hspace= None)

sns.heatmap(heat_cm0, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[0])
ax[0].set_title('Voting Classifier\n', fontsize = 50)
sns.heatmap(heat_cm1, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[1])
ax[1].set_title('Random Forest Classifier\n', fontsize = 50)
sns.heatmap(heat_cm2, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[2])
ax[2].set_title('Logistic Regression Classifier\n', fontsize = 50)
sns.heatmap(heat_cm3, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[3])
ax[3].set_title('SVM Classifier\n', fontsize = 50)
sns.heatmap(heat_cm4, cmap="Blues", annot=True, annot_kws={"size": 60},fmt='g', ax = ax[4])
ax[4].set_title('MLP Classifier\n', fontsize = 50)

plt.show()

# %%
df.isnull().sum()
# Out:
# 총자산대비현금            0
# 산업평균대비현금           0
# 매출채권회전율            0
# 매출총이익률             0
# 대손률                0
# 총자산대비매출채권          0
# 산업평균대비매출채권         0
# 총자산대비금융자산          0
# 총자산대비단기금융자산        0
# 금융자산수익률            0
# 단기금융자산수익률          0
# 총자산대비유가증권          0
# 유가증권수익률            0
# 산업평균대비유가증권         0
# 유형자산감가상각률          0
# 산업평균대비유형자산감가상각률    0
# 총자산대비유형자산          0
# 산업평균대비유형자산         0
# 무형자산상각률            0
# 산업평균대비무형자산상각률      0
# 총자산대비무형자산          0
# 개발비계상비율            0
# 산업평균대비무형자산         0
# 재고자산회전율            0
# 매출원가율              0
# 총자산대비재고            0
# 산업평균대비재고           0
# 유효이자율              0
# 단기유효이자율            0
# 총자산대비차입금           0
# 산업평균대비차입금          0
# 역마진여부              0
# 단기역마진여부            0
# 감사의견               0
# dtype: int64

# %% [markdown]
# ### 혹시 군집분석이 가능할까?

# %% [markdown]
# 개실패

# %%
from sklearn.cluster import KMeans

# %%
df_cluster = pd.read_csv(r'C:\Users\awdrg\Documents\Documents\텀플 데이터\3rd 주요계정강화\4. CSV파일화\제조업_주요계정 강화 - 복사본 - 복사본.csv',
           encoding='cp949', thousands = ',')
df_cluster

# %%
df_cluster = df_cluster.dropna(subset = ['Name'])
df_cluster.drop('Name', axis = 1, inplace = True)
df_cluster['감사의견']=df_cluster['감사의견'].apply(lambda x : 0 if x == '적정의견' 
                            else (0 if x[0:4] == '한정의견' else 1 ))
df_cluster.shape

# %% [markdown]
# * 군집화모형

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300,random_state=0)
# 3 실패

# %% [markdown]
# ### 전처리 전 데이터로 군집화

# %%
kmeans.fit(df_cluster.iloc[:,:33])

# %%
print(kmeans.labels_)

# %%
np.unique(kmeans.labels_, return_counts=True)

# %%
df_cluster['cluster']=kmeans.labels_
df_cluster.head()

# %%
df_cluster_result = df_cluster.groupby(['감사의견','cluster'])['감사의견'].count()

# %%
df_cluster_result

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(df_cluster.iloc[:,:33])
    # irisDF 로 하면 이미 추가된 값들이 pca 를 방해함. 반드시 원본데이터를 넣어아.

df_cluster['pca_x'] = pca_transformed[:,0]
df_cluster['pca_y'] = pca_transformed[:,1]
    # pac후 X,y 값을 DF에 추가하는 작업.
df_cluster.head(3)

# %%
# cluster 값이 0, 1, 2 인 경우마다 Index를 별도로 추출
marker0_ind = df_cluster[df_cluster['cluster']==0].index
marker1_ind = df_cluster[df_cluster['cluster']==1].index
marker2_ind = df_cluster[df_cluster['cluster']==2].index

# cluster값 0, 1, 2에 해당하는 Index로 각 cluster 레벨의 pca_x, pca_y 값 추출. o, s, ^ 로 marker 표시
plt.scatter(x=df_cluster.loc[marker0_ind,'pca_x'], y=df_cluster.loc[marker0_ind,'pca_y'], marker='o') 
plt.scatter(x=df_cluster.loc[marker1_ind,'pca_x'], y=df_cluster.loc[marker1_ind,'pca_y'], marker='s')
plt.scatter(x=df_cluster.loc[marker2_ind,'pca_x'], y=df_cluster.loc[marker2_ind,'pca_y'], marker='^')

    # loc 을 사용할 때 행 값으로 1) boolean조건을 주거나 2) 행 index를 줄 수 있음.
    # loc[행 조건, 열 조건]
    
    # s 는 사각형, o 는 원, ^ 는 세모
    

plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('3 Clusters Visualization by 2 PCA Components')
plt.show()

# %% [markdown]
# ### 전처리 후 데이터로 군집화

# %%
df_cluster = df_removed2

# %%
df_cluster.shape

# %% [markdown]
# * 군집화모형

# %%
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300,random_state=0)
# 3 실패

# %% [markdown]
# * 전처리 전 데이터로 군집화

# %%
kmeans.fit(df_cluster.iloc[:,:df_cluster.shape[1]-1])

# %%
print(kmeans.labels_)

# %%
np.unique(kmeans.labels_, return_counts=True)

# %%
df_cluster['cluster']=kmeans.labels_
df_cluster.head()

# %%
df_cluster_result = df_cluster.groupby(['감사의견','cluster'])['감사의견'].count()

# %%
df_cluster_result

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca_transformed = pca.fit_transform(df_cluster.iloc[:,:33])
    # irisDF 로 하면 이미 추가된 값들이 pca 를 방해함. 반드시 원본데이터를 넣어아.

df_cluster['pca_x'] = pca_transformed[:,0]
df_cluster['pca_y'] = pca_transformed[:,1]
    # pac후 X,y 값을 DF에 추가하는 작업.
df_cluster.head(3)

# %%
# cluster 값이 0, 1, 2 인 경우마다 Index를 별도로 추출
marker0_ind = df_cluster[df_cluster['cluster']==0].index
marker1_ind = df_cluster[df_cluster['cluster']==1].index
marker2_ind = df_cluster[df_cluster['cluster']==2].index

# cluster값 0, 1, 2에 해당하는 Index로 각 cluster 레벨의 pca_x, pca_y 값 추출. o, s, ^ 로 marker 표시
plt.scatter(x=df_cluster.loc[marker0_ind,'pca_x'], y=df_cluster.loc[marker0_ind,'pca_y'], marker='o') 
plt.scatter(x=df_cluster.loc[marker1_ind,'pca_x'], y=df_cluster.loc[marker1_ind,'pca_y'], marker='s')
plt.scatter(x=df_cluster.loc[marker2_ind,'pca_x'], y=df_cluster.loc[marker2_ind,'pca_y'], marker='^')

    # loc 을 사용할 때 행 값으로 1) boolean조건을 주거나 2) 행 index를 줄 수 있음.
    # loc[행 조건, 열 조건]
    
    # s 는 사각형, o 는 원, ^ 는 세모
    

plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('3 Clusters Visualization by 2 PCA Components')
plt.show()

# %% [markdown]
# # 2. Null 값 제거

# %% [markdown]
# 2.1 Name 에 없는 값은 제거.

# %%
df = df.dropna(subset = ['Name'])
df.head(3)

# %%
df.shape

# %% [markdown]
# 2.2. Name 필드 제거

# %%
df.drop('Name', axis = 1, inplace = True)

# %%
df.head(3)

# %%
df.isnull().sum()

# %%
df.info()

# %%
df.describe()

# %%
df['감사의견'].value_counts().to_frame()

# %%
df = df.drop(df[df['감사의견']=='0'].index, axis = 0)
df['감사의견'].value_counts().to_frame()

# 틀린 이유: 가로를 지울 것이므로 axis = 0 으로 했어야 함. 
# index 는  list 로 바꿀 필요는 없음

# %%
df['감사의견']=df['감사의견'].apply(lambda x : 0 if x == '적정의견' 
                            else (0 if x[0:4] == '한정의견' else 1 ))

# %%
df['감사의견'].value_counts()

# %%
round(df['감사의견'].value_counts()/len(df),2)

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ### 폰트깨짐 해결

# %% [markdown]
# #### Nanum 폰트가 인식될 때 'Nanum Malgun Gothic' 이 아니라 'Malgun Gothic' 으로 인식이 되는 것이 었습니다.

# %%
# 폰트 설정 방법 1
import matplotlib.pyplot as plt

# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='Malgun Gothic') # For Windows
print(plt.rcParams['font.family'])

# %matplotlib inline
# 브라우저에서 바로 이미지를 그린다.

# %% [markdown]
# 3.1. 감사의견 분포

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(df['감사의견'])
plt.xlabel('Audit Opinion')
plt.title('Audit Opinion Distribution')

# %% [markdown]
# 3.2. 히스토그램

# %%
df.hist(figsize = (35,30), bins = 50)
plt.show()

# %% [markdown]
# 3.3. 상관관계분석

# %%
f, ax = plt.subplots(figsize=(30, 25))

mat = df.corr('spearman')
mask = np.triu(np.ones_like(mat, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(mat, mask=mask, cmap=cmap, vmax=1, center=0, annot = True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# * 순위확인

# %%
mat['감사의견'].abs().sort_values(ascending = False)[1:11]

# %%
mat['감사의견'].sort_values(ascending = False)[1:6]

# 오히려 토지를 차감 안하는게 낫다는 것인가?

# %%
mat['감사의견'].sort_values(ascending = True)[:5]

# %% [markdown]
# 3.4. 피쳐별 분포확인

# %%
plt.figure(figsize = (20,15))
ax =sns.boxplot(data = df, orient="h")
ax.set_title('Audit Data Boxplots', fontsize = 18)
ax.set(xscale="log")
plt.show()

# %% [markdown]
# 3.5. 감사의견별 분포확인

# %%
for j in range(6):
    cols = df.columns[j*6:(j+1)*6]

    n=0
    f, axes = plt.subplots(ncols=6, figsize=(24,4))

    for i in cols:
        sns.boxplot(x= '감사의견', y= i , data=df, ax=axes[n])
        axes[n].set_title(i, fontsize=14)
        n=n+1
    plt.show()

# %% [markdown]
# * 아래는 감사의견 == 1 인 값만 추출하여 다시 히스토그램 그리는 것. 착각주의

# %%
for j in range(6):

    f, axes = plt.subplots(1,6, figsize=(24, 4))

    cols = df.columns[j*6:(j+1)*6]
    colors = ['#FB8861','#56F9BB','#C5B3F9','#FB8861','#56F9BB','#C5B3F9']
    
    n = 0
    
    for i, l in zip(cols, colors):
        sns.distplot(df[i].loc[df['감사의견']== 1] ,ax= axes[n], color= l) # fit=norm 왜 안되냐?
        axes[n].set_title(i + '\n (Unstable companies)', fontsize=14)
        n+=1
    plt.show()
    
    
# 이상치들이 극단적으로 많은 것을 볼 수 있음.

# %%
for j,i in enumerate(range(df.shape[1])):
    
    print('{0}. {1}:' .format(j,df.columns[i]))
    print("    1. Skewness: %f" % df.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df.iloc[:,i].kurt())
    
# df[i] 를 하면  self._engine.get_loc(casted_key) 오류 발생
    # => i는 iloc으로 찾아야지 ㅄ아

# %%
Skewness = []
Kurtosis = []
for i in range(df.shape[1]):    
    Skewness.append(df.iloc[:,i].skew())
    Kurtosis.append(df.iloc[:,i].kurt())

# %%
# 마지막 값만 남음. 아니 왜???
# 아.. 병신아. 변수를 안에 설정하니까 다시 초기화되지....

# %% [markdown]
# # 4. 이상치 제거

# %%
for col in df:
    print(col)

# %% [markdown]
# ## 4.1. 하나의 컬럼에 대해서만 없애는 방법

# %%
def outliers_removal(feature,feature_name,dataset):
    
    # Identify 25th & 75th quartiles

    q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
    feat_iqr = q75 - q25    
    feat_cut_off = feat_iqr * 1.5
    feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off
    
    outliers = [x for x in feature if x < feat_lower or x > feat_upper]
    print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
    #print(feature_name + ' outliers:{}'.format(outliers))

    dataset = dataset.drop(dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index)
    print(len(dataset))
    
    print('-' * 65)
    
    return dataset

df_removed1 = outliers_removal(df['총자산대비무형자산'],'총자산대비무형자산',df)
    
# 이러면 맨 마지막 것만 떨어지므로 감사의견만 1이 제거됨. 병신임.

# %%
df_removed1

# %%
df_removed1['감사의견'].value_counts()

# %% [raw]
# 원래 값은 다음과 같음. 거의 200개에 가까운 target이 떨어져 나감.
# >* 0 :   12980
# >* 1 :   751

# %%
(12980-11354)/12980

# %%
(751- 574) /751
# 거의 2배 가깝게 떨어짐. 이거 괜찮은건가?
# 이게 어떠한 예측력을 갖는 것인가?

# %% [markdown]
# * 분포재확인

# %%
for j,i in enumerate(range(df_removed1.shape[1])):
    
    print('{0}. {1}:' .format(j,df_removed1.columns[i]))
    print("    1. Skewness: %f" % df_removed1.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df_removed1.iloc[:,i].kurt())

# %% [markdown]
# ## 4.2 모든 컬럼에 대해 없애는 방법

# %%
def outliers_removal(dataset):
    
    drop_index = set([])
    
    for col in dataset.columns[:-1]:
        
        feature = dataset[col]
        feature_name = col
        
        
        q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
        feat_iqr = q75 - q25    
        feat_cut_off = feat_iqr * 1.5
        feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off

        outliers = [x for x in feature if x < feat_lower or x > feat_upper]
        print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
        #print(feature_name + ' outliers:{}'.format(outliers))

        
        removal_index = dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index
        
        drop_index.update(list(removal_index))
        
        # k.update([3, 4, 5]) : 집합에 여러 값 추가시 사용
        
        print('제거 레코드 수: %d' %len(drop_index))

        print('-' * 65)
    
    dataset = dataset.drop(list(drop_index))  

    print('남은 레코드 수: %d' %len(dataset))
    
    return dataset
       
        
df_removed2 = outliers_removal(df)

# %%
df_removed2

# %%
for j,i in enumerate(range(df_removed2.shape[1])):
    
    print('{0}. {1}:' .format(j,df_removed2.columns[i]))
    print("    1. Skewness: %f" % df_removed2.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df_removed2.iloc[:,i].kurt())

# %%
df_removed2['감사의견'].value_counts()

# %%
def draw_boxplot(dataset, horizental_number, vertical_number):
        
    for j in range(vertical_number):
        cols = dataset.columns[j*horizental_number:(j+1)*horizental_number]

        n=0
        f, axes = plt.subplots(ncols=horizental_number, figsize=(24,24/horizental_number))

        for i in cols:
            sns.boxplot(x= '감사의견', y= i , data=dataset, ax=axes[n])
            axes[n].set_title(i, fontsize = 14)
            n=n+1
        plt.show()
        
draw_boxplot(df_removed2, 6,6)

# %%
def draw_distplot(dataset, horizental_number, vertical_number):
    
    for j in range(vertical_number):

        f, axes = plt.subplots(1,horizental_number, figsize=(24, 24/horizental_number))

        cols = dataset.columns[j*horizental_number:(j+1)*horizental_number]
        colors = ['#FB8861','#56F9BB','#C5B3F9']*2

        n = 0

        for i, l in zip(cols, colors):
            sns.distplot(dataset[i].loc[df['감사의견']== 1] ,ax= axes[n], color= l) # fit=norm 왜 안되냐?
            axes[n].set_title(i, fontsize=14)
            n+=1
        plt.show()
        
draw_distplot(df_removed2,6,6)

# %% [markdown]
# 4.3. 상하위 1%에 대해서만 없애는방법

# %% [markdown]
# * 이 방법 어디 정리해 놓은 것 같은데 찾아봐야.

# %% [markdown]
# # 5. 타겟 데이터 Oversampling

# %% [markdown]
# 아래 모형학습에 포함.

# %% [markdown]
# 이거 안했더니 전부 yes 로 찍고 점수 받더라... 지금 큰일난거

# %% [markdown]
# # 6. 모형학습

# %% [markdown]
# ## 6.1. 하나만 없앤 데이터 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from keras import models
from keras import layers

# %% [markdown]
# * SMOTE 를 이용하여 오버샘플링

# %%
from imblearn.over_sampling import SMOTE

# %%
X=df_removed1.drop(labels=['감사의견'], axis=1)
y=df_removed1['감사의견']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
# X.shape, y.shape : ((22708, 33), (22708,))
# df_removed1.shape : (11928, 34)
# X.shape[0]/df_removed1.shape[0] : 1.903755868544601

# %%
sns.countplot(x=y)

# %% [markdown]
# * 학습에 사용할 피쳐 선택

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest

# %% [markdown]
# StandardScaler
# * Select 30 independent variables out of 96 variables.
# * 이거 Stratified Cross Validation Splitting 아니면 필요 없는데
# * 애초에 Stratified Cross Validation Splitting 이 무엇인가, 필요한가?

# %%
feature_selection=SelectKBest(f_classif,k=20).fit(X,y)
selected_features=X.columns[feature_selection.get_support()]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

# %%
for i in [X_train, X_test, y_train, y_test]:
    print(i.shape)

# %% [markdown]
# ### 6.1.1. 앙상블 보팅으로 예측

# %%
dt_clf = DecisionTreeClassifier()
knn_clf = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier( estimators=[('DT',dt_clf),('KNN',knn_clf)] , voting='soft' )

# %%
vo_clf.fit(X_train , y_train)

# %%
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))

# 정확도가 올라갔다... 왜?
# 아 개오바야....

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))

# %% [markdown]
# * 개별모델 예측 평가

# %%
classifiers = [dt_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train , y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test , pred)))
    
    print(classification_report(y_test,pred,target_names=['yes','no']))
    print(confusion_matrix(y_test,pred),'\n')
    
# 왜 정확도가 같다고 나오지???
# 하나로 찍으니까 그렇게 나오지.

# 참고로, 로지스틱은 정규화 하고 넣어야 한다.

# %% [markdown]
# ### 6.1.2. 랜덤포레스트로 예측

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)

# %%
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

# %%
ftr_importances = pd.Series(rf_clf.feature_importances_,index=df_removed1.columns[0:-1])

ftr_importances.sort_values(ascending = False).to_frame()

# %%
ftr_importances_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_importances_top20.values , y = ftr_importances_top20.index)
plt.show()

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))

# 랜덤포레스트는 나쁘지 않다.

# %% [markdown]
# ### 6.1.3. 로지스틱회귀분석 예측

# %% [markdown]
# * 정규화

# %%
scaler=StandardScaler()
X_scale=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y,test_size=0.3)

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train,y_train)

# %%
lr_clf.score(X_test,y_test)

# 성능이 유의적으로 오르긴 하였으나 거의 쓸모가 없음.

# %% [markdown]
# * Metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
pred = lr_clf.predict(X_test)

# %%
accuracy_score(y_test,pred)

# %%
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))

# %% [markdown]
# ### 6.1.4 서포트벡터머신 예측

# %% [markdown]
# * 서포트벡터머신 : 패턴 인식, 자료 분석을 위한 지도 학습 모델이며, 주로 분류와 회귀 분석을 위해 사용

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train, y_train)

# %%
model.score(X_test,y_test)

# 이상치 제거 전후가 왜 이렇게 유의적으로 차이가 나는거지?

# %%
svc_predict=model.predict(X_test)

# %%
print(classification_report(y_test, svc_predict))
print(confusion_matrix(y_test,svc_predict))

# 개수 보면 오류는 아니다.

# %% [markdown]
# ### 6.1.5. 인공신경망으로 예측

# %% [markdown]
# * Minmax scaling

# %%
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , random_state= 156)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# * 모형생성 및 학습

# %%
model=models.Sequential()
model.add(layers.Dense(4, activation='relu',input_dim=X_train.shape[1]))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,
                 epochs=200,batch_size=128,
                 validation_split=0.3, class_weight={0:1,1:1}) # class_weight={0:0.0506,1:1} 

# smote 했으므로 가중치 1:1 로 학습.

# %%
predicted_result=model.predict(X_test)
predicted_result.shape

# %%
predicted_target=pd.Series([1 if predicted_result[i]> 0.5 \
         else 0 for i in range(0,predicted_result.shape[0])])

# %%
accuracy = accuracy_score(y_test , predicted_target)
print('인공신경망 정확도: {0:.4f}'.format(accuracy))

# %%
print(classification_report(y_test,predicted_target,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,predicted_target))

# 정확도만 높고 나머지는 병신인데? 이유가 뭐냐
# 해당 피쳐들로는 맞는것을 고르기는 쉬운데 아닌 것을 고르는게 거의 불가능.

# 아니 왜 하나로 쳐 미는데...
# => 점수를 이런 식으로 주면 19:1 의 비율로 존재하므로 한 값으로 밀어도 95점이 나오는 것. 그래서 이렇게...

# %%
history_dict=history.history
history_dict.keys()

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)

# %%
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot(epochs,acc,'bo',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.2 전부 없앤 데이터 학습

# %% [markdown]
# * SMOTE 를 이용하여 오버샘플링

# %%
X=df_removed2.drop(labels=['감사의견'], axis=1)
y=df_removed2['감사의견']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
# X.shape, y.shape : ((4090, 33), (4090,))
# df_removed2.shape : (2091, 34)
# X.shape[0]/df_removed2.shape[0] : 1.9560019129603061

# %%
sns.countplot(x=y)

# %% [markdown]
# * 학습에 사용할 피쳐 선택

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest

# %%
feature_selection=SelectKBest(f_classif,k=20).fit(X,y)
selected_features=X.columns[feature_selection.get_support()]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

# %%
for i in [X_train, X_test, y_train, y_test]:
    print(i.shape)

# %% [markdown]
# ### 6.2.1. 앙상블 보팅으로 예측

# %%
dt_clf = DecisionTreeClassifier()
knn_clf = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier( estimators=[('DT',dt_clf),('KNN',knn_clf)] , voting='soft' )

# %%
vo_clf.fit(X_train , y_train)

# %%
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))

# 정확도가 올라갔다... 왜?
# 아 개오바야....

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))

# %% [markdown]
# * 개별모델 예측 평가

# %%
classifiers = [dt_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train , y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test , pred)))
    
    print(classification_report(y_test,pred,target_names=['yes','no']))
    print(confusion_matrix(y_test,pred),'\n')
    
# 왜 정확도가 같다고 나오지???
# 하나로 찍으니까 그렇게 나오지.

# 참고로, 로지스틱은 정규화 하고 넣어야 한다.

# %% [markdown]
# ### 6.2.2. 랜덤포레스트로 예측

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)

# %%
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

# %%
ftr_importances = pd.Series(rf_clf.feature_importances_,index=df_removed1.columns[0:-1])

top_ftr_importances = ftr_importances.sort_values(ascending = False).to_frame()
top_ftr_importances

# %%
top_index = top_ftr_importances.index[:5]
top_index

# %%
for i in top_index:
    sns.boxplot(x= '감사의견', y= i , data=df_removed2)
    plt.show()
    
# 1에서는 단기금융자산은 없었는데 이게 효과가 좋네. 그냥 금융자산이랑 다르다.
# 1인 기업의 단기금융자산, 현금, 유가증권 등이 없는 것으로 볼 때 자금경색으로 경영난을 겪고 있는 기업일 가능성이 높다.

# %%
import math

plt.rcParams["font.size"]=14

def draw_boxplot(dataset, columns, horizental_number, vertical_number):
        
    for j in range(vertical_number):
        cols = columns[j*horizental_number:(j+1)*horizental_number]

        n=0
        f, axes = plt.subplots(ncols=horizental_number, figsize=(12,12/horizental_number))

        for i in cols:
            sns.boxplot(x= '감사의견', y= i , data=dataset, ax=axes[n])
            axes[n].set_title(i, fontsize=16)
            axes[n].set_ylabel("")
            
            n=n+1
        plt.show()

horizental_number = 3
draw_boxplot(df_removed2, top_index, horizental_number, math.ceil(len(top_index)/horizental_number))

# %%
ftr_importances_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_importances_top20.values , y = ftr_importances_top20.index)
plt.show()

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))

# 랜덤포레스트는 나쁘지 않다.

# %% [markdown]
# ### 6.1.3. 로지스틱회귀분석 예측

# %% [markdown]
# * 정규화

# %%
scaler=StandardScaler()
X_scale=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y,test_size=0.3)

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train,y_train)

# %%
lr_clf.score(X_test,y_test)

# 성능이 유의적으로 오르긴 하였으나 거의 쓸모가 없음.

# %% [markdown]
# * Metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
pred = lr_clf.predict(X_test)

# %%
accuracy_score(y_test,pred)

# %%
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))

# %% [markdown]
# ### 6.1.4 서포트벡터머신 예측

# %% [markdown]
# * 서포트벡터머신 : 패턴 인식, 자료 분석을 위한 지도 학습 모델이며, 주로 분류와 회귀 분석을 위해 사용

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train, y_train)

# %%
model.score(X_test,y_test)

# 이상치 제거 전후가 왜 이렇게 유의적으로 차이가 나는거지?

# %%
svc_predict=model.predict(X_test)

# %%
print(classification_report(y_test, svc_predict))
print(confusion_matrix(y_test,svc_predict))

# 개수 보면 오류는 아니다.

# %% [markdown]
# ### 6.1.5. 인공신경망으로 예측

# %% [markdown]
# * Minmax scaling

# %%
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , random_state= 156)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# * 모형생성 및 학습

# %%
model=models.Sequential()
model.add(layers.Dense(4, activation='relu',input_dim=X_train.shape[1]))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,
                 epochs=200,batch_size=128,
                 validation_split=0.3, class_weight={0:1,1:1}) # class_weight={0:0.0506,1:1} 

# smote 했으므로 가중치 1:1 로 학습.

# %%
predicted_result=model.predict(X_test)
predicted_result.shape

# %%
predicted_target=pd.Series([1 if predicted_result[i]> 0.5 \
         else 0 for i in range(0,predicted_result.shape[0])])

# %%
accuracy = accuracy_score(y_test , predicted_target)
print('인공신경망 정확도: {0:.4f}'.format(accuracy))

# %%
print(classification_report(y_test,predicted_target,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,predicted_target))

# 정확도만 높고 나머지는 병신인데? 이유가 뭐냐
# 해당 피쳐들로는 맞는것을 고르기는 쉬운데 아닌 것을 고르는게 거의 불가능.

# 아니 왜 하나로 쳐 미는데...
# => 점수를 이런 식으로 주면 19:1 의 비율로 존재하므로 한 값으로 밀어도 95점이 나오는 것. 그래서 이렇게...

# %%
history_dict=history.history
history_dict.keys()

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)

# %%
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot(epochs,acc,'bo',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()
