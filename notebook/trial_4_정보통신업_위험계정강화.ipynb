# %% [markdown]
# # 1. 데이터 불러오기

# %%
import os
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\awdrg\Documents\Documents\텀플 데이터\3rd 주요계정강화\4. CSV파일화\정보통신업_주요계정 강화 - 복사본 - 복사본.csv',
           encoding='cp949', thousands = ',')
df.head(3)

# pd.read_csv() 에서 thousands = ',' 옵션으로 천 단위 자리수 구분 콤마 없애고 불러오기
# Out:
#     Name   총자산대비현금  산업평균대비현금    매출채권회전율  매출총이익률       대손률  총자산대비매출채권  \
# 0  NAVER  0.082556 -0.077783   0.000000     1.0  0.000000   0.000000
# 1    카카오  0.229658  0.069319  15.414236     1.0  0.008934   0.017477
# 2  SK텔레콤  0.028233 -0.132106   8.752803     1.0  0.000000   0.061903
#
#    산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  ...  매출원가율   총자산대비재고      산업평균대비재고  \
# 0   -0.082094          0     0.038185  ...    0.0  0.000182  5.201560e-09
# 1   -0.064618          0     0.084877  ...    0.0  0.004030  3.848037e-03
# 2   -0.020191          0     0.019883  ...    0.0  0.006620  6.437904e-03
#
#       유효이자율  단기유효이자율  총자산대비차입금     산업평균대비차입금     역마진여부   단기역마진여부  감사의견
# 0  0.011401        0  0.117582  2.081670e-16 -0.011401  0.015550  적정의견
# 1  0.011938        0  0.144848  2.726618e-02 -0.011938  0.019079  적정의견
# 2  0.025981        0  0.348319  2.307371e-01 -0.025981  0.059725  적정의견
#
# [3 rows x 35 columns]

# %%
df.shape
# Out:
# (3775, 35)

# %%
df.isnull().sum()
# Out:
# Name               2040
# 총자산대비현금               0
# 산업평균대비현금           2040
# 매출채권회전율               0
# 매출총이익률                0
# 대손률                   0
# 총자산대비매출채권             0
# 산업평균대비매출채권         2040
# 총자산대비금융자산             0
# 총자산대비단기금융자산           0
# 금융자산수익률               0
# 단기금융자산수익률             0
# 총자산대비유가증권             0
# 유가증권수익률               0
# 산업평균대비유가증권         2040
# 유형자산감가상각률             0
# 산업평균대비유형자산감가상각률    2040
# 총자산대비유형자산             0
# 산업평균대비유형자산         2040
# 무형자산상각률               0
# 산업평균대비무형자산상각률      2040
# 총자산대비무형자산             0
# 개발비계상비율               0
# 산업평균대비무형자산         2040
# 재고자산회전율               0
# 매출원가율                 0
# 총자산대비재고               0
# 산업평균대비재고           2040
# 유효이자율                 0
# 단기유효이자율               0
# 총자산대비차입금              0
# 산업평균대비차입금          2040
# 역마진여부                 0
# 단기역마진여부               0
# 감사의견                  0
# dtype: int64

# %% [markdown]
# # 2. Null 값 제거

# %% [markdown]
# 2.1 Name 에 없는 값은 제거.

# %%
df = df.dropna(subset = ['Name'])
df.shape
# Out:
# (1735, 35)

# %% [markdown]
# 2.2. Name 필드 제거

# %%
df.drop('Name', axis = 1, inplace = True)

# %%
df= df.dropna(axis = 1,how = 'all')
df.head(3)
# Out:
#     총자산대비현금  산업평균대비현금    매출채권회전율  매출총이익률       대손률  총자산대비매출채권  산업평균대비매출채권  \
# 0  0.082556 -0.077783   0.000000     1.0  0.000000   0.000000   -0.082094
# 1  0.229658  0.069319  15.414236     1.0  0.008934   0.017477   -0.064618
# 2  0.028233 -0.132106   8.752803     1.0  0.000000   0.061903   -0.020191
#
#    총자산대비금융자산  총자산대비단기금융자산  금융자산수익률  ...  매출원가율   총자산대비재고      산업평균대비재고  \
# 0          0     0.038185        0  ...    0.0  0.000182  5.201560e-09
# 1          0     0.084877        0  ...    0.0  0.004030  3.848037e-03
# 2          0     0.019883        0  ...    0.0  0.006620  6.437904e-03
#
#       유효이자율  단기유효이자율  총자산대비차입금     산업평균대비차입금     역마진여부   단기역마진여부  감사의견
# 0  0.011401        0  0.117582  2.081670e-16 -0.011401  0.015550  적정의견
# 1  0.011938        0  0.144848  2.726618e-02 -0.011938  0.019079  적정의견
# 2  0.025981        0  0.348319  2.307371e-01 -0.025981  0.059725  적정의견
#
# [3 rows x 34 columns]

# %%
df.isnull().sum()
# Out:
# 총자산대비현금            0
# 산업평균대비현금           0
# 매출채권회전율            0
# 매출총이익률             0
# 대손률                0
# 총자산대비매출채권          0
# 산업평균대비매출채권         0
# 총자산대비금융자산          0
# 총자산대비단기금융자산        0
# 금융자산수익률            0
# 단기금융자산수익률          0
# 총자산대비유가증권          0
# 유가증권수익률            0
# 산업평균대비유가증권         0
# 유형자산감가상각률          0
# 산업평균대비유형자산감가상각률    0
# 총자산대비유형자산          0
# 산업평균대비유형자산         0
# 무형자산상각률            0
# 산업평균대비무형자산상각률      0
# 총자산대비무형자산          0
# 개발비계상비율            0
# 산업평균대비무형자산         0
# 재고자산회전율            0
# 매출원가율              0
# 총자산대비재고            0
# 산업평균대비재고           0
# 유효이자율              0
# 단기유효이자율            0
# 총자산대비차입금           0
# 산업평균대비차입금          0
# 역마진여부              0
# 단기역마진여부            0
# 감사의견               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1735 entries, 0 to 3774
# Data columns (total 34 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   총자산대비현금          1735 non-null   float64
#  1   산업평균대비현금         1735 non-null   float64
#  2   매출채권회전율          1735 non-null   float64
#  3   매출총이익률           1735 non-null   float64
#  4   대손률              1735 non-null   float64
#  5   총자산대비매출채권        1735 non-null   float64
#  6   산업평균대비매출채권       1735 non-null   float64
#  7   총자산대비금융자산        1735 non-null   int64
#  8   총자산대비단기금융자산      1735 non-null   float64
#  9   금융자산수익률          1735 non-null   int64
#  10  단기금융자산수익률        1735 non-null   float64
#  11  총자산대비유가증권        1735 non-null   int64
#  12  유가증권수익률          1735 non-null   int64
#  13  산업평균대비유가증권       1735 non-null   float64
#  14  유형자산감가상각률        1735 non-null   float64
#  15  산업평균대비유형자산감가상각률  1735 non-null   float64
#  16  총자산대비유형자산        1735 non-null   float64
#  17  산업평균대비유형자산       1735 non-null   float64
#  18  무형자산상각률          1735 non-null   float64
#  19  산업평균대비무형자산상각률    1735 non-null   float64
#  20  총자산대비무형자산        1735 non-null   float64
#  21  개발비계상비율          1735 non-null   float64
#  22  산업평균대비무형자산       1735 non-null   float64
#  23  재고자산회전율          1735 non-null   float64
#  24  매출원가율            1735 non-null   float64
#  25  총자산대비재고          1735 non-null   float64
#  26  산업평균대비재고         1735 non-null   float64
#  27  유효이자율            1735 non-null   float64
#  28  단기유효이자율          1735 non-null   int64
#  29  총자산대비차입금         1735 non-null   float64
#  30  산업평균대비차입금        1735 non-null   float64
#  31  역마진여부            1735 non-null   float64
#  32  단기역마진여부          1735 non-null   float64
#  33  감사의견             1735 non-null   object
# dtypes: float64(28), int64(5), object(1)
# memory usage: 474.4+ KB

# %%
df.describe()
# Out:
#            총자산대비현금      산업평균대비현금       매출채권회전율       매출총이익률          대손률  \
# count  1735.000000  1.735000e+03   1735.000000  1735.000000  1735.000000
# mean      0.210267  4.992790e-02     71.639436     0.535342     3.839236
# std       0.189144  1.891439e-01    901.416784     0.666860   106.182534
# min       0.000000 -1.603392e-01    -46.424471   -15.186379  -100.762895
# 25%       0.068755 -9.158394e-02      4.522208     0.210030     0.000000
# 50%       0.160339 -3.330670e-16      7.565764     0.491563     0.000000
# 75%       0.295307  1.349677e-01     13.310976     1.000000     0.010101
# max       0.977465  8.171256e-01  30292.286340     1.648833  3125.000000
#
#          총자산대비매출채권   산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  금융자산수익률  ...  \
# count  1735.000000  1735.000000     1735.0  1735.000000   1735.0  ...
# mean      0.124736     0.042641        0.0     0.136286      0.0  ...
# std       0.128787     0.128787        0.0     0.177446      0.0  ...
# min       0.000000    -0.082094        0.0    -0.005805      0.0  ...
# 25%       0.031511    -0.050583        0.0     0.002769      0.0  ...
# 50%       0.082094     0.000000        0.0     0.061977      0.0  ...
# 75%       0.182656     0.100562        0.0     0.203786      0.0  ...
# max       0.896748     0.814653        0.0     0.949803      0.0  ...
#
#              재고자산회전율        매출원가율      총자산대비재고     산업평균대비재고        유효이자율  \
# count    1735.000000  1735.000000  1735.000000  1735.000000  1735.000000
# mean      324.540540     0.456013     0.033626     0.033444     0.974532
# std      4023.748381     0.666345     0.084713     0.084713    34.103210
# min         0.000000    -0.648833     0.000000    -0.000182     0.000000
# 25%         0.000000     0.000000     0.000000    -0.000182     0.013671
# 50%         0.000000     0.492724     0.000182     0.000000     0.027621
# 75%        11.596046     0.784230     0.023160     0.022978     0.048834
# max    120049.418500    16.186379     0.977361     0.977179  1414.000000
#
#        단기유효이자율     총자산대비차입금     산업평균대비차입금        역마진여부        단기역마진여부
# count   1735.0  1735.000000  1.735000e+03  1735.000000    1735.000000
# mean       0.0     0.250563  1.329818e-01    -0.974532      61.546168
# std        0.0     0.731417  7.314167e-01    34.103210    2499.627601
# min        0.0     0.000000 -1.175816e-01 -1414.000000      -1.118720
# 25%        0.0     0.014977 -1.026046e-01    -0.048834       0.006201
# 50%        0.0     0.117582  2.081670e-16    -0.027621       0.017828
# 75%        0.0     0.321690  2.041088e-01    -0.013671       0.054786
# max        0.0    21.038963  2.092138e+01     0.000000  104105.000000
#
# [8 rows x 33 columns]

# %%
df['감사의견'].value_counts().to_frame()
# Out:
#                감사의견
# 적정의견           1546
# 0               129
# 한정의견(감사범위제한)     27
# 의견거절(불확실성)       16
# 의견거절(감사범위제한)     12
# 한정의견(불확실성)        3
# 보고서미제출            1
# 부적정의견(GAAP위반)     1

# %%
df = df.drop(df[df['감사의견']=='0'].index, axis = 0)
df['감사의견'].value_counts().to_frame()

# 틀린 이유: 가로를 지울 것이므로 axis = 0 으로 했어야 함. 
# index 는  list 로 바꿀 필요는 없음
# Out:
#                감사의견
# 적정의견           1546
# 한정의견(감사범위제한)     27
# 의견거절(불확실성)       16
# 의견거절(감사범위제한)     12
# 한정의견(불확실성)        3
# 보고서미제출            1
# 부적정의견(GAAP위반)     1

# %%
df['감사의견']=df['감사의견'].apply(lambda x : 0 if x == '적정의견' 
                            else (0 if x[0:4] == '한정의견' else 1 ))

# %%
df['감사의견'].value_counts()
# Out:
# 0    1576
# 1      30
# Name: 감사의견, dtype: int64

# %%
round(df['감사의견'].value_counts()/len(df),2)
# Out:
# 0    0.98
# 1    0.02
# Name: 감사의견, dtype: float64

# %%
df.shape
# Out:
# (1606, 34)

# %% [markdown]
# # 3. EDA

# %% [markdown]
# ### 폰트깨짐 해결

# %% [markdown]
# #### Nanum 폰트가 인식될 때 'Nanum Malgun Gothic' 이 아니라 'Malgun Gothic' 으로 인식이 되는 것이 었습니다.

# %%
# 폰트 설정 방법 1
import matplotlib.pyplot as plt

# matplotlib 폰트설정
# plt.rc('font', family='NanumGothicOTF') # For MacOS
plt.rc('font', family='Malgun Gothic') # For Windows
print(plt.rcParams['font.family'])

# %matplotlib inline
# 브라우저에서 바로 이미지를 그린다.
# Out:
# ['Malgun Gothic']

# %% [markdown]
# 3.1. 감사의견 분포

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.countplot(df['감사의견'])
plt.xlabel('Audit Opinion')
plt.title('Audit Opinion Distribution')
# Out:
# Text(0.5, 1.0, 'Audit Opinion Distribution')

# %% [markdown]
# 3.2. 히스토그램

# %%
df.hist(figsize = (35,30), bins = 50)
plt.show()

# %% [markdown]
# 3.3. 상관관계분석

# %%
f, ax = plt.subplots(figsize=(30, 25))

mat = df.corr('spearman')
mask = np.triu(np.ones_like(mat, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(mat, mask=mask, cmap=cmap, vmax=1, center=0, annot = True,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# * 순위확인

# %%
mat['감사의견'].abs().sort_values(ascending = False)[1:11]
# Out:
# 산업평균대비현금      0.089324
# 총자산대비현금       0.089324
# 총자산대비매출채권     0.085237
# 산업평균대비매출채권    0.085237
# 산업평균대비차입금     0.082695
# 총자산대비차입금      0.082695
# 유효이자율         0.078193
# 역마진여부         0.078193
# 단기역마진여부       0.046594
# 단기금융자산수익률     0.046594
# Name: 감사의견, dtype: float64

# %%
mat['감사의견'].sort_values(ascending = False)[1:6]

# 오히려 토지를 차감 안하는게 낫다는 것인가?
# Out:
# 산업평균대비차입금    0.082695
# 총자산대비차입금     0.082695
# 유효이자율        0.078193
# 단기금융자산수익률    0.046594
# 단기역마진여부      0.046594
# Name: 감사의견, dtype: float64

# %%
mat['감사의견'].sort_values(ascending = True)[:5]
# Out:
# 총자산대비현금      -0.089324
# 산업평균대비현금     -0.089324
# 총자산대비매출채권    -0.085237
# 산업평균대비매출채권   -0.085237
# 역마진여부        -0.078193
# Name: 감사의견, dtype: float64

# %% [markdown]
# 3.4. 피쳐별 분포확인

# %%
plt.figure(figsize = (20,16))
ax =sns.boxplot(data = df, orient="h")
ax.set_title('Audit Data Boxplots', fontsize = 18)
ax.set(xscale="log")
plt.show()

# 중심이 없는 값은 무엇인가 => 0에 몰려있는 잘못된 데이터
# 사용이 불가능 할 것으로 보임...
# Out:
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '-' [U+2212], substituting with a dummy symbol.

# %% [markdown]
# 3.5. 감사의견별 분포확인

# %%
for j in range(6):
    cols = df.columns[j*6:(j+1)*6]

    n=0
    f, axes = plt.subplots(ncols=6, figsize=(24,4))

    for i in cols:
        sns.boxplot(x= '감사의견', y= i , data=df, ax=axes[n])
        axes[n].set_title(n)
        n=n+1
    plt.show()
    
# 유의적 차이를 보이는 피쳐가 없다.

# %% [markdown]
# * 아래는 히스토그램이랑 같은데 왜 그리는 것인지?
#
#     정규분포 때문인가?

# %%
for j in range(6):

    f, axes = plt.subplots(1,6, figsize=(24, 4))

    cols = df.columns[j*6:(j+1)*6]
    colors = ['#FB8861','#56F9BB','#C5B3F9','#FB8861','#56F9BB','#C5B3F9']
    
    n = 0
    
    for i, l in zip(cols, colors):
        sns.distplot(df[i].loc[df['감사의견']== 1] ,ax= axes[n], color= l) # fit=norm 왜 안되냐?
        axes[n].set_title(i + '\n (Unstable companies)', fontsize=14)
        n+=1
    plt.show()
    
    
# 이상치는 적어졌는데 낙타가 생김...
# 낙타형태는 애초에 계정값이 0이었던 필드가 많아서 그렇게 된 것으로 보임.

# %%
for j,i in enumerate(range(df.shape[1])):
    
    print('{0}. {1}:' .format(j,df.columns[i]))
    print("    1. Skewness: %f" % df.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df.iloc[:,i].kurt())
    
# df[i] 를 하면  self._engine.get_loc(casted_key) 오류 발생
    # => i는 iloc으로 찾아야지 ㅄ아
# Out:
# 0. 총자산대비현금:
#     1. Skewness: 1.332995
#     2. Kurtosis: 1.507848
#
# 1. 산업평균대비현금:
#     1. Skewness: 1.332995
#     2. Kurtosis: 1.507848
#
# 2. 매출채권회전율:
#     1. Skewness: 24.934107
#     2. Kurtosis: 727.154561
#
# 3. 매출총이익률:
#     1. Skewness: -15.223345
#     2. Kurtosis: 345.493179
#
# 4. 대손률:
#     1. Skewness: 28.214772
#     2. Kurtosis: 796.834750
#
# 5. 총자산대비매출채권:
#     1. Skewness: 1.591527
#     2. Kurtosis: 2.842499
#
# 6. 산업평균대비매출채권:
#     1. Skewness: 1.591527
#     2. Kurtosis: 2.842499
#
# 7. 총자산대비금융자산:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 8. 총자산대비단기금융자산:
#     1. Skewness: 1.743815
#     2. Kurtosis: 2.900297
#
# 9. 금융자산수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 10. 단기금융자산수익률:
#     1. Skewness: 40.058526
#     2. Kurtosis: 1605.113883
#
# 11. 총자산대비유가증권:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 12. 유가증권수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 13. 산업평균대비유가증권:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 14. 유형자산감가상각률:
#     1. Skewness: -28.310738
#     2. Kurtosis: 800.494846
#
# 15. 산업평균대비유형자산감가상각률:
#     1. Skewness: -28.310738
#     2. Kurtosis: 800.494846
#
# 16. 총자산대비유형자산:
#     1. Skewness: 1.660753
#     2. Kurtosis: 1.882149
#
# 17. 산업평균대비유형자산:
#     1. Skewness: 1.660753
#     2. Kurtosis: 1.882149
#
# 18. 무형자산상각률:
#     1. Skewness: 39.959808
#     2. Kurtosis: 1599.678105
#
# 19. 산업평균대비무형자산상각률:
#     1. Skewness: 39.959808
#     2. Kurtosis: 1599.678105
#
# 20. 총자산대비무형자산:
#     1. Skewness: 3.329439
#     2. Kurtosis: 13.282098
#
# 21. 개발비계상비율:
#     1. Skewness: 2.126870
#     2. Kurtosis: 2.826511
#
# 22. 산업평균대비무형자산:
#     1. Skewness: 2.126870
#     2. Kurtosis: 2.826511
#
# 23. 재고자산회전율:
#     1. Skewness: 22.074233
#     2. Kurtosis: 544.423472
#
# 24. 매출원가율:
#     1. Skewness: 15.294097
#     2. Kurtosis: 347.462597
#
# 25. 총자산대비재고:
#     1. Skewness: 4.706096
#     2. Kurtosis: 31.647891
#
# 26. 산업평균대비재고:
#     1. Skewness: 4.706096
#     2. Kurtosis: 31.647891
#
# 27. 유효이자율:
#     1. Skewness: 39.548077
#     2. Kurtosis: 1576.119866
#
# 28. 단기유효이자율:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 29. 총자산대비차입금:
#     1. Skewness: 20.698080
#     2. Kurtosis: 525.010961
#
# 30. 산업평균대비차입금:
#     1. Skewness: 20.698080
#     2. Kurtosis: 525.010961
#
# 31. 역마진여부:
#     1. Skewness: -39.548077
#     2. Kurtosis: 1576.119866
#
# 32. 단기역마진여부:
#     1. Skewness: 40.058526
#     2. Kurtosis: 1605.113883
#
# 33. 감사의견:
#     1. Skewness: 7.116668
#     2. Kurtosis: 48.707613

# %%
Skewness = []
Kurtosis = []
for i in range(df.shape[1]):    
    Skewness.append(df.iloc[:,i].skew())
    Kurtosis.append(df.iloc[:,i].kurt())

# %%
# 마지막 값만 남음. 아니 왜???
# 아.. 병신아. 변수를 안에 설정하니까 다시 초기화되지....

# %% [markdown]
# # 4. 이상치 제거

# %%
for col in df:
    print(col)
# Out:
# 총자산대비현금
# 산업평균대비현금
# 매출채권회전율
# 매출총이익률
# 대손률
# 총자산대비매출채권
# 산업평균대비매출채권
# 총자산대비금융자산
# 총자산대비단기금융자산
# 금융자산수익률
# 단기금융자산수익률
# 총자산대비유가증권
# 유가증권수익률
# 산업평균대비유가증권
# 유형자산감가상각률
# 산업평균대비유형자산감가상각률
# 총자산대비유형자산
# 산업평균대비유형자산
# 무형자산상각률
# 산업평균대비무형자산상각률
# 총자산대비무형자산
# 개발비계상비율
# 산업평균대비무형자산
# 재고자산회전율
# 매출원가율
# 총자산대비재고
# 산업평균대비재고
# 유효이자율
# 단기유효이자율
# 총자산대비차입금
# 산업평균대비차입금
# 역마진여부
# 단기역마진여부
# 감사의견

# %% [markdown]
# ## 4.1. 하나의 컬럼에 대해서만 없애는 방법

# %%
def outliers_removal(feature,feature_name,dataset):
    
    # Identify 25th & 75th quartiles

    q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
    feat_iqr = q75 - q25    
    feat_cut_off = feat_iqr * 1.5
    feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off
    
    outliers = [x for x in feature if x < feat_lower or x > feat_upper]
    print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
    #print(feature_name + ' outliers:{}'.format(outliers))

    dataset = dataset.drop(dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index) 
    print('-' * 65)
    print(len(dataset))
    
    return dataset

df_removed1 = outliers_removal(df['총자산대비무형자산'],'총자산대비무형자산',df)
    
# 이러면 맨 마지막 것만 떨어지므로 감사의견만 1이 제거됨. 병신임.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 20>()
#      16     print(len(dataset))
#      18     return dataset
# ---> 20 df_removed1 = outliers_removal(df['총자산대비무형자산'],'총자산대비무형자산',df)
#
# NameError: name 'df' is not defined

# %%
df_removed1
# Out:
#        총자산대비현금  산업평균대비현금     매출채권회전율    매출총이익률       대손률  총자산대비매출채권  \
# 0     0.082556 -0.077783    0.000000  1.000000  0.000000   0.000000
# 3     0.055860 -0.104480    8.307501  1.000000 -0.010812   0.060656
# 4     0.081261 -0.079079    8.347005  1.000000  0.000000   0.080272
# 5     0.102771 -0.057568    7.103192  0.123490 -0.000354   0.182445
# 8     0.039768 -0.120572    7.855333  1.000000  0.040521   0.091029
# ...        ...       ...         ...       ...       ...        ...
# 3768  0.021092 -0.139247    2.152823  0.169925  0.000000   0.504419
# 3769  0.736169  0.575830   14.157226  1.000000  0.000000   0.021186
# 3770  0.372200  0.211861  665.792000  1.000000  0.000000   0.000934
# 3771  0.927466  0.767127    0.000000  1.000000  0.000000   0.000000
# 3774  0.208079  0.047739   10.431551  1.000000  0.000000   0.443096
#
#       산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  금융자산수익률  ...     매출원가율   총자산대비재고  \
# 0      -0.082094          0     0.038185        0  ...  0.000000  0.000182
# 3      -0.021438          0     0.394213        0  ...  0.000000  0.001392
# 4      -0.001822          0     0.031907        0  ...  0.000000  0.013836
# 5       0.100351          0     0.333760        0  ...  0.876510  0.004212
# 8       0.008934          0     0.006297        0  ...  0.000000  0.012460
# ...          ...        ...          ...      ...  ...       ...       ...
# 3768    0.422324          0     0.015586        0  ...  0.830075  0.000000
# 3769   -0.060909          0     0.000000        0  ...  0.000000  0.000000
# 3770   -0.081161          0     0.207333        0  ...  0.000000  0.000000
# 3771   -0.082094          0     0.029639        0  ...  0.000000  0.000000
# 3774    0.361002          0     0.026948        0  ...  0.000000  0.000000
#
#           산업평균대비재고     유효이자율  단기유효이자율  총자산대비차입금     산업평균대비차입금     역마진여부  \
# 0     5.201560e-09  0.011401        0  0.117582  2.081670e-16 -0.011401
# 3     1.209654e-03  0.017045        0  0.168663  5.108180e-02 -0.017045
# 4     1.365399e-02  0.027445        0  0.258268  1.406865e-01 -0.027445
# 5     4.030040e-03  0.038196        0  0.043933 -7.364865e-02 -0.038196
# 8     1.227809e-02  0.021688        0  0.364548  2.469662e-01 -0.021688
# ...            ...       ...      ...       ...           ...       ...
# 3768 -1.822360e-04  0.122890        0  0.292185  1.746035e-01 -0.122890
# 3769 -1.822360e-04  0.018910        0  0.433507  3.159250e-01 -0.018910
# 3770 -1.822360e-04  0.094160        0  0.368292  2.507106e-01 -0.094160
# 3771 -1.822360e-04  0.000000        0  0.000000 -1.175816e-01  0.000000
# 3774 -1.822360e-04  0.036244        0  3.079873  2.962291e+00 -0.036244
#
#        단기역마진여부  감사의견
# 0     0.015550     0
# 3     0.015727     0
# 4     0.230640     0
# 5     0.017323     0
# 8     0.447695     0
# ...        ...   ...
# 3768  0.078431     0
# 3769  0.000000     0
# 3770  0.014587     0
# 3771  0.131296     0
# 3774  0.734550     0
#
# [1406 rows x 34 columns]

# %%
df_removed1['감사의견'].value_counts()
# Out:
# 0    1384
# 1      22
# Name: 감사의견, dtype: int64

# %% [markdown]
# * 분포재확인

# %%
for j,i in enumerate(range(df_removed1.shape[1])):
    
    print('{0}. {1}:' .format(j,df_removed1.columns[i]))
    print("    1. Skewness: %f" % df_removed1.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df_removed1.iloc[:,i].kurt())
# Out:
# 0. 총자산대비현금:
#     1. Skewness: 1.274983
#     2. Kurtosis: 1.259101
#
# 1. 산업평균대비현금:
#     1. Skewness: 1.274983
#     2. Kurtosis: 1.259101
#
# 2. 매출채권회전율:
#     1. Skewness: 23.330346
#     2. Kurtosis: 636.558289
#
# 3. 매출총이익률:
#     1. Skewness: -15.225315
#     2. Kurtosis: 331.199124
#
# 4. 대손률:
#     1. Skewness: 26.396050
#     2. Kurtosis: 697.291763
#
# 5. 총자산대비매출채권:
#     1. Skewness: 1.594904
#     2. Kurtosis: 2.771178
#
# 6. 산업평균대비매출채권:
#     1. Skewness: 1.594904
#     2. Kurtosis: 2.771178
#
# 7. 총자산대비금융자산:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 8. 총자산대비단기금융자산:
#     1. Skewness: 1.717955
#     2. Kurtosis: 2.789570
#
# 9. 금융자산수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 10. 단기금융자산수익률:
#     1. Skewness: 37.481318
#     2. Kurtosis: 1405.224146
#
# 11. 총자산대비유가증권:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 12. 유가증권수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 13. 산업평균대비유가증권:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 14. 유형자산감가상각률:
#     1. Skewness: -26.485801
#     2. Kurtosis: 700.494158
#
# 15. 산업평균대비유형자산감가상각률:
#     1. Skewness: -26.485801
#     2. Kurtosis: 700.494158
#
# 16. 총자산대비유형자산:
#     1. Skewness: 1.518700
#     2. Kurtosis: 1.317776
#
# 17. 산업평균대비유형자산:
#     1. Skewness: 1.518700
#     2. Kurtosis: 1.317776
#
# 18. 무형자산상각률:
#     1. Skewness: 37.388938
#     2. Kurtosis: 1400.464248
#
# 19. 산업평균대비무형자산상각률:
#     1. Skewness: 37.388938
#     2. Kurtosis: 1400.464248
#
# 20. 총자산대비무형자산:
#     1. Skewness: 1.761920
#     2. Kurtosis: 2.308079
#
# 21. 개발비계상비율:
#     1. Skewness: 2.473679
#     2. Kurtosis: 4.510247
#
# 22. 산업평균대비무형자산:
#     1. Skewness: 2.473679
#     2. Kurtosis: 4.510247
#
# 23. 재고자산회전율:
#     1. Skewness: 20.659838
#     2. Kurtosis: 476.650639
#
# 24. 매출원가율:
#     1. Skewness: 15.289828
#     2. Kurtosis: 332.903942
#
# 25. 총자산대비재고:
#     1. Skewness: 4.554346
#     2. Kurtosis: 29.305707
#
# 26. 산업평균대비재고:
#     1. Skewness: 4.554346
#     2. Kurtosis: 29.305707
#
# 27. 유효이자율:
#     1. Skewness: 37.003868
#     2. Kurtosis: 1379.846014
#
# 28. 단기유효이자율:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 29. 총자산대비차입금:
#     1. Skewness: 23.759039
#     2. Kurtosis: 743.186821
#
# 30. 산업평균대비차입금:
#     1. Skewness: 23.759039
#     2. Kurtosis: 743.186821
#
# 31. 역마진여부:
#     1. Skewness: -37.003868
#     2. Kurtosis: 1379.846014
#
# 32. 단기역마진여부:
#     1. Skewness: 37.481318
#     2. Kurtosis: 1405.224146
#
# 33. 감사의견:
#     1. Skewness: 7.813785
#     2. Kurtosis: 59.139353

# %% [markdown]
# ## 4.2 모든 컬럼에 대해 없애는 방법

# %%
def outliers_removal(dataset):
    
    drop_index = set([])
    
    for col in dataset.columns[:-1]:
        
        feature = dataset[col]
        feature_name = col
        
        
        q25, q75 = np.percentile(feature, 25), np.percentile(feature, 75)
        feat_iqr = q75 - q25    
        feat_cut_off = feat_iqr * 1.5
        feat_lower, feat_upper = q25 - feat_cut_off, q75 + feat_cut_off

        outliers = [x for x in feature if x < feat_lower or x > feat_upper]
        print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
        #print(feature_name + ' outliers:{}'.format(outliers))

        
        removal_index = dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index
        
        drop_index.update(list(removal_index))
        
        # k.update([3, 4, 5]) : 집합에 여러 값 추가시 사용
        
        print('제거 레코드 수: %d' %len(drop_index))

        print('-' * 65)
    
    dataset = dataset.drop(list(drop_index))    
    print('남은 레코드 수: %d' %len(dataset))

    
    return dataset
       
        
df_removed2 = outliers_removal(df)

# 남은 레코드 수: 238 => 이거로는 안된다. 1% 지우기로 간다.
# Out:
# 총자산대비현금 Amount of outliers: 67
# 제거 레코드 수: 67
# -----------------------------------------------------------------
# 산업평균대비현금 Amount of outliers: 67
# 제거 레코드 수: 67
# -----------------------------------------------------------------
# 매출채권회전율 Amount of outliers: 189
# 제거 레코드 수: 242
# -----------------------------------------------------------------
# 매출총이익률 Amount of outliers: 8
# 제거 레코드 수: 248
# -----------------------------------------------------------------
# 대손률 Amount of outliers: 364
# 제거 레코드 수: 540
# -----------------------------------------------------------------
# 총자산대비매출채권 Amount of outliers: 64
# 제거 레코드 수: 598
# -----------------------------------------------------------------
# 산업평균대비매출채권 Amount of outliers: 64
# 제거 레코드 수: 598
# -----------------------------------------------------------------
# 총자산대비금융자산 Amount of outliers: 0
# 제거 레코드 수: 598
# -----------------------------------------------------------------
# 총자산대비단기금융자산 Amount of outliers: 92
# 제거 레코드 수: 662
# -----------------------------------------------------------------
# 금융자산수익률 Amount of outliers: 0
# 제거 레코드 수: 662
# -----------------------------------------------------------------
# 단기금융자산수익률 Amount of outliers: 249
# 제거 레코드 수: 799
# -----------------------------------------------------------------
# 총자산대비유가증권 Amount of outliers: 0
# 제거 레코드 수: 799
# -----------------------------------------------------------------
# 유가증권수익률 Amount of outliers: 0
# 제거 레코드 수: 799
# -----------------------------------------------------------------
# 산업평균대비유가증권 Amount of outliers: 0
# 제거 레코드 수: 799
# -----------------------------------------------------------------
# 유형자산감가상각률 Amount of outliers: 142
# 제거 레코드 수: 868
# -----------------------------------------------------------------
# 산업평균대비유형자산감가상각률 Amount of outliers: 142
# 제거 레코드 수: 868
# -----------------------------------------------------------------
# 총자산대비유형자산 Amount of outliers: 157
# 제거 레코드 수: 947
# -----------------------------------------------------------------
# 산업평균대비유형자산 Amount of outliers: 157
# 제거 레코드 수: 947
# -----------------------------------------------------------------
# 무형자산상각률 Amount of outliers: 146
# 제거 레코드 수: 995
# -----------------------------------------------------------------
# 산업평균대비무형자산상각률 Amount of outliers: 146
# 제거 레코드 수: 995
# -----------------------------------------------------------------
# 총자산대비무형자산 Amount of outliers: 200
# 제거 레코드 수: 1092
# -----------------------------------------------------------------
# 개발비계상비율 Amount of outliers: 344
# 제거 레코드 수: 1205
# -----------------------------------------------------------------
# 산업평균대비무형자산 Amount of outliers: 344
# 제거 레코드 수: 1205
# -----------------------------------------------------------------
# 재고자산회전율 Amount of outliers: 297
# 제거 레코드 수: 1272
# -----------------------------------------------------------------
# 매출원가율 Amount of outliers: 9
# 제거 레코드 수: 1273
# -----------------------------------------------------------------
# 총자산대비재고 Amount of outliers: 276
# 제거 레코드 수: 1354
# -----------------------------------------------------------------
# 산업평균대비재고 Amount of outliers: 276
# 제거 레코드 수: 1354
# -----------------------------------------------------------------
# 유효이자율 Amount of outliers: 182
# 제거 레코드 수: 1376
# -----------------------------------------------------------------
# 단기유효이자율 Amount of outliers: 0
# 제거 레코드 수: 1376
# -----------------------------------------------------------------
# 총자산대비차입금 Amount of outliers: 73
# 제거 레코드 수: 1386
# -----------------------------------------------------------------
# 산업평균대비차입금 Amount of outliers: 73
# 제거 레코드 수: 1386
# -----------------------------------------------------------------
# 역마진여부 Amount of outliers: 182
# 제거 레코드 수: 1386
# -----------------------------------------------------------------
# 단기역마진여부 Amount of outliers: 249
# 제거 레코드 수: 1386
# -----------------------------------------------------------------
# 남은 레코드 수: 220

# %%
df_removed2
# Out:
#        총자산대비현금  산업평균대비현금    매출채권회전율    매출총이익률       대손률  총자산대비매출채권  \
# 0     0.082556 -0.077783   0.000000  1.000000  0.000000   0.000000
# 3     0.055860 -0.104480   8.307501  1.000000 -0.010812   0.060656
# 20    0.463197  0.302858   3.428899  1.000000  0.000000   0.145127
# 23    0.197016  0.036677  10.851001  1.000000  0.008095   0.058563
# 27    0.197335  0.036996   8.182305  1.000000  0.000000   0.055547
# ...        ...       ...        ...       ...       ...        ...
# 3709  0.363957  0.203618  11.118441  1.000000  0.000000   0.122676
# 3726  0.002753 -0.157586   1.110832  0.311674  0.000000   0.294442
# 3728  0.130166 -0.030174   0.495211  0.679366  0.000000   0.236571
# 3731  0.323268  0.162929   8.062195  1.000000  0.000000   0.100548
# 3732  0.215875  0.055536   4.582116  1.000000  0.000000   0.322834
#
#       산업평균대비매출채권  총자산대비금융자산  총자산대비단기금융자산  금융자산수익률  ...     매출원가율   총자산대비재고  \
# 0      -0.082094          0     0.038185        0  ...  0.000000  0.000182
# 3      -0.021438          0     0.394213        0  ...  0.000000  0.001392
# 20      0.063033          0     0.228761        0  ...  0.000000  0.000000
# 23     -0.023531          0     0.107288        0  ...  0.000000  0.016030
# 27     -0.026547          0     0.206804        0  ...  0.000000  0.000038
# ...          ...        ...          ...      ...  ...       ...       ...
# 3709    0.040581          0     0.162809        0  ...  0.000000  0.000000
# 3726    0.212348          0     0.169404        0  ...  0.688325  0.000000
# 3728    0.154477          0     0.002366        0  ...  0.320634  0.000000
# 3731    0.018454          0     0.008111        0  ...  0.000000  0.000000
# 3732    0.240740          0     0.000000        0  ...  0.000000  0.000000
#
#           산업평균대비재고     유효이자율  단기유효이자율  총자산대비차입금     산업평균대비차입금     역마진여부  \
# 0     5.201560e-09  0.011401        0  0.117582  2.081670e-16 -0.011401
# 3     1.209654e-03  0.017045        0  0.168663  5.108180e-02 -0.017045
# 20   -1.822360e-04  0.035659        0  0.108127 -9.454096e-03 -0.035659
# 23    1.584756e-02  0.054481        0  0.037134 -8.044767e-02 -0.054481
# 27   -1.441330e-04  0.001982        0  0.036235 -8.134670e-02 -0.001982
# ...            ...       ...      ...       ...           ...       ...
# 3709 -1.822360e-04  0.017333        0  0.000695 -1.168863e-01 -0.017333
# 3726 -1.822360e-04  0.031768        0  0.323828  2.062466e-01 -0.031768
# 3728 -1.822360e-04  0.000500        0  0.006411 -1.111708e-01 -0.000500
# 3731 -1.822360e-04  0.026586        0  0.466294  3.487126e-01 -0.026586
# 3732 -1.822360e-04  0.054610        0  0.296315  1.787337e-01 -0.054610
#
#        단기역마진여부  감사의견
# 0     0.015550     0
# 3     0.015727     0
# 20    0.021149     0
# 23    0.014440     0
# 27    0.010750     0
# ...        ...   ...
# 3709  0.016178     0
# 3726  0.036390     0
# 3728  0.002846     0
# 3731  0.088379     0
# 3732  0.000000     0
#
# [220 rows x 34 columns]

# %% [markdown]
# ### 이번엔 이 방식을 사용할 수 없다. 1%만 제거

# %% [markdown]
# ## 4.3. 상하위 1%에 대해서만 없애는방법

# %% [markdown]
# * 이 방법 어디 정리해 놓은 것 같은데 찾아봐야.
# * but 1% 만 없애는 것이 옳은 제거법인가? 아무 데이터나 1% 잘라버리면 어쩌라고?

# %%
def top_removal(dataset):
    
    drop_index = set([])
    
    for col in dataset.columns[:-1]:
        
        feature = dataset[col]
        feature_name = col
        
        
        feat_upper, feat_lower = np.percentile(feature, 99), np.percentile(feature, 1)

        outliers = [x for x in feature if x < feat_lower or x > feat_upper]
        print(feature_name + ' Amount of outliers: {}'.format(len(outliers)))
        #print(feature_name + ' outliers:{}'.format(outliers))

        
        removal_index = dataset[(dataset[feature_name] > feat_upper) | (dataset[feature_name] < feat_lower)].index
        
        drop_index.update(list(removal_index))
        
        # k.update([3, 4, 5]) : 집합에 여러 값 추가시 사용
        
        print('제거 레코드 수: %d' %len(drop_index))

        print('-' * 65)
    
    dataset = dataset.drop(list(drop_index))    
    print('남은 레코드 수: %d' %len(dataset))

    
    return dataset
       
        
df_removed2 = top_removal(df)

# 남은 레코드 수: 238 => 이거로는 안된다. 1% 지우기로 간다.
# np.percentile => 1% = 하위 1% 를 의미.
# Out:
# 총자산대비현금 Amount of outliers: 34
# 제거 레코드 수: 34
# -----------------------------------------------------------------
# 산업평균대비현금 Amount of outliers: 34
# 제거 레코드 수: 34
# -----------------------------------------------------------------
# 매출채권회전율 Amount of outliers: 18
# 제거 레코드 수: 50
# -----------------------------------------------------------------
# 매출총이익률 Amount of outliers: 18
# 제거 레코드 수: 62
# -----------------------------------------------------------------
# 대손률 Amount of outliers: 34
# 제거 레코드 수: 88
# -----------------------------------------------------------------
# 총자산대비매출채권 Amount of outliers: 17
# 제거 레코드 수: 105
# -----------------------------------------------------------------
# 산업평균대비매출채권 Amount of outliers: 17
# 제거 레코드 수: 105
# -----------------------------------------------------------------
# 총자산대비금융자산 Amount of outliers: 0
# 제거 레코드 수: 105
# -----------------------------------------------------------------
# 총자산대비단기금융자산 Amount of outliers: 19
# 제거 레코드 수: 122
# -----------------------------------------------------------------
# 금융자산수익률 Amount of outliers: 0
# 제거 레코드 수: 122
# -----------------------------------------------------------------
# 단기금융자산수익률 Amount of outliers: 19
# 제거 레코드 수: 139
# -----------------------------------------------------------------
# 총자산대비유가증권 Amount of outliers: 0
# 제거 레코드 수: 139
# -----------------------------------------------------------------
# 유가증권수익률 Amount of outliers: 0
# 제거 레코드 수: 139
# -----------------------------------------------------------------
# 산업평균대비유가증권 Amount of outliers: 0
# 제거 레코드 수: 139
# -----------------------------------------------------------------
# 유형자산감가상각률 Amount of outliers: 19
# 제거 레코드 수: 158
# -----------------------------------------------------------------
# 산업평균대비유형자산감가상각률 Amount of outliers: 19
# 제거 레코드 수: 158
# -----------------------------------------------------------------
# 총자산대비유형자산 Amount of outliers: 19
# 제거 레코드 수: 172
# -----------------------------------------------------------------
# 산업평균대비유형자산 Amount of outliers: 19
# 제거 레코드 수: 172
# -----------------------------------------------------------------
# 무형자산상각률 Amount of outliers: 17
# 제거 레코드 수: 187
# -----------------------------------------------------------------
# 산업평균대비무형자산상각률 Amount of outliers: 17
# 제거 레코드 수: 187
# -----------------------------------------------------------------
# 총자산대비무형자산 Amount of outliers: 17
# 제거 레코드 수: 202
# -----------------------------------------------------------------
# 개발비계상비율 Amount of outliers: 0
# 제거 레코드 수: 202
# -----------------------------------------------------------------
# 산업평균대비무형자산 Amount of outliers: 0
# 제거 레코드 수: 202
# -----------------------------------------------------------------
# 재고자산회전율 Amount of outliers: 17
# 제거 레코드 수: 218
# -----------------------------------------------------------------
# 매출원가율 Amount of outliers: 18
# 제거 레코드 수: 218
# -----------------------------------------------------------------
# 총자산대비재고 Amount of outliers: 17
# 제거 레코드 수: 231
# -----------------------------------------------------------------
# 산업평균대비재고 Amount of outliers: 17
# 제거 레코드 수: 231
# -----------------------------------------------------------------
# 유효이자율 Amount of outliers: 17
# 제거 레코드 수: 243
# -----------------------------------------------------------------
# 단기유효이자율 Amount of outliers: 0
# 제거 레코드 수: 243
# -----------------------------------------------------------------
# 총자산대비차입금 Amount of outliers: 17
# 제거 레코드 수: 252
# -----------------------------------------------------------------
# 산업평균대비차입금 Amount of outliers: 17
# 제거 레코드 수: 252
# -----------------------------------------------------------------
# 역마진여부 Amount of outliers: 17
# 제거 레코드 수: 252
# -----------------------------------------------------------------
# 단기역마진여부 Amount of outliers: 19
# 제거 레코드 수: 252
# -----------------------------------------------------------------
# 남은 레코드 수: 1354

# %%
for j,i in enumerate(range(df_removed2.shape[1])):
    
    print('{0}. {1}:' .format(j,df_removed2.columns[i]))
    print("    1. Skewness: %f" % df_removed2.iloc[:,i].skew())
    print("    2. Kurtosis: %f\n" % df_removed2.iloc[:,i].kurt())
# Out:
# 0. 총자산대비현금:
#     1. Skewness: 1.172582
#     2. Kurtosis: 0.920296
#
# 1. 산업평균대비현금:
#     1. Skewness: 1.172582
#     2. Kurtosis: 0.920296
#
# 2. 매출채권회전율:
#     1. Skewness: 10.490270
#     2. Kurtosis: 135.157096
#
# 3. 매출총이익률:
#     1. Skewness: 0.076689
#     2. Kurtosis: -1.607601
#
# 4. 대손률:
#     1. Skewness: 10.154665
#     2. Kurtosis: 125.095683
#
# 5. 총자산대비매출채권:
#     1. Skewness: 1.246764
#     2. Kurtosis: 0.969782
#
# 6. 산업평균대비매출채권:
#     1. Skewness: 1.246764
#     2. Kurtosis: 0.969782
#
# 7. 총자산대비금융자산:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 8. 총자산대비단기금융자산:
#     1. Skewness: 1.467303
#     2. Kurtosis: 1.516158
#
# 9. 금융자산수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 10. 단기금융자산수익률:
#     1. Skewness: 8.607030
#     2. Kurtosis: 89.814492
#
# 11. 총자산대비유가증권:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 12. 유가증권수익률:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 13. 산업평균대비유가증권:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 14. 유형자산감가상각률:
#     1. Skewness: 4.588989
#     2. Kurtosis: 31.628344
#
# 15. 산업평균대비유형자산감가상각률:
#     1. Skewness: 4.588989
#     2. Kurtosis: 31.628344
#
# 16. 총자산대비유형자산:
#     1. Skewness: 1.579188
#     2. Kurtosis: 1.610165
#
# 17. 산업평균대비유형자산:
#     1. Skewness: 1.579188
#     2. Kurtosis: 1.610165
#
# 18. 무형자산상각률:
#     1. Skewness: 7.496010
#     2. Kurtosis: 87.595358
#
# 19. 산업평균대비무형자산상각률:
#     1. Skewness: 7.496010
#     2. Kurtosis: 87.595358
#
# 20. 총자산대비무형자산:
#     1. Skewness: 2.638018
#     2. Kurtosis: 7.608280
#
# 21. 개발비계상비율:
#     1. Skewness: 2.017626
#     2. Kurtosis: 2.367161
#
# 22. 산업평균대비무형자산:
#     1. Skewness: 2.017626
#     2. Kurtosis: 2.367161
#
# 23. 재고자산회전율:
#     1. Skewness: 6.275131
#     2. Kurtosis: 44.624750
#
# 24. 매출원가율:
#     1. Skewness: -0.058324
#     2. Kurtosis: -1.618908
#
# 25. 총자산대비재고:
#     1. Skewness: 2.963608
#     2. Kurtosis: 9.270183
#
# 26. 산업평균대비재고:
#     1. Skewness: 2.963608
#     2. Kurtosis: 9.270183
#
# 27. 유효이자율:
#     1. Skewness: 5.440540
#     2. Kurtosis: 34.484990
#
# 28. 단기유효이자율:
#     1. Skewness: 0.000000
#     2. Kurtosis: 0.000000
#
# 29. 총자산대비차입금:
#     1. Skewness: 1.923267
#     2. Kurtosis: 5.230277
#
# 30. 산업평균대비차입금:
#     1. Skewness: 1.923267
#     2. Kurtosis: 5.230277
#
# 31. 역마진여부:
#     1. Skewness: -5.440540
#     2. Kurtosis: 34.484990
#
# 32. 단기역마진여부:
#     1. Skewness: 8.607030
#     2. Kurtosis: 89.814492
#
# 33. 감사의견:
#     1. Skewness: 8.508587
#     2. Kurtosis: 70.500195

# %%
df_removed2['감사의견'].value_counts()
# Out:
# 0    1336
# 1      18
# Name: 감사의견, dtype: int64

# %%
def draw_boxplot(dataset, horizental_number, vertical_number):
        
    for j in range(vertical_number):
        cols = dataset.columns[j*horizental_number:(j+1)*horizental_number]

        n=0
        f, axes = plt.subplots(ncols=horizental_number, figsize=(24,24/horizental_number))

        for i in cols:
            sns.boxplot(x= '감사의견', y= i , data=dataset, ax=axes[n])
            axes[n].set_title(i, fontsize = 14)
            n=n+1
        plt.show()
        
draw_boxplot(df_removed2, 6,6)

# %%
def draw_distplot(dataset, horizental_number, vertical_number):
    
    for j in range(vertical_number):

        f, axes = plt.subplots(1,horizental_number, figsize=(24, 24/horizental_number))

        cols = dataset.columns[j*horizental_number:(j+1)*horizental_number]
        colors = ['#FB8861','#56F9BB','#C5B3F9']*2

        n = 0

        for i, l in zip(cols, colors):
            sns.distplot(dataset[i].loc[df['감사의견']== 1] ,ax= axes[n], color= l) # fit=norm 왜 안되냐?
            axes[n].set_title(i + '\n (Unstable companies)', fontsize=14)
            n+=1
        plt.show()
        
draw_distplot(df_removed2,6,6)

# %% [markdown]
# # 5. 모형학습

# %% [markdown]
# # 5. 타겟 데이터 Oversampling

# %% [markdown]
# 아래 모형학습에 포함.

# %% [markdown]
# 이거 안했더니 전부 yes 로 찍고 점수 받더라... 지금 큰일난거

# %% [markdown]
# # 6. 모형학습

# %% [markdown]
# ## 6.1. 하나만 없앤 데이터 학습

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from keras import models
from keras import layers

# %% [markdown]
# * SMOTE 를 이용하여 오버샘플링

# %%
from imblearn.over_sampling import SMOTE

# %%
X=df_removed1.drop(labels=['감사의견'], axis=1)
y=df_removed1['감사의견']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 X=df_removed1.drop(labels=['감사의견'], axis=1)
#       2 y=df_removed1['감사의견']
#
# NameError: name 'df_removed1' is not defined

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
X.shape, y.shape 
# df_removed1.shape : (11928, 34)
# X.shape[0]/df_removed1.shape[0] : 1.903755868544601

# %%
sns.countplot(x=y)
# Out:
# <AxesSubplot:xlabel='감사의견', ylabel='count'>

# %% [markdown]
# * 학습에 사용할 피쳐 선택

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest

# %% [markdown]
# StandardScaler
# * Select 30 independent variables out of 96 variables.
# * 이거 Stratified Cross Validation Splitting 아니면 필요 없는데
# * 애초에 Stratified Cross Validation Splitting 이 무엇인가, 필요한가?

# %%
feature_selection=SelectKBest(f_classif,k=20).fit(X,y)
selected_features=X.columns[feature_selection.get_support()]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

# %%
for i in [X_train, X_test, y_train, y_test]:
    print(i.shape)
# Out:
# (1937, 33)
# (831, 33)
# (1937,)
# (831,)

# %% [markdown]
# ### 6.1.1. 앙상블 보팅으로 예측

# %%
dt_clf = DecisionTreeClassifier()
knn_clf = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier( estimators=[('DT',dt_clf),('KNN',knn_clf)] , voting='soft' )

# %%
vo_clf.fit(X_train , y_train)
# Out:
# VotingClassifier(estimators=[('DT', DecisionTreeClassifier()),
#                              ('KNN', KNeighborsClassifier(n_neighbors=8))],
#                  voting='soft')

# %%
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))

# 정확도가 올라갔다... 왜?
# 아 개오바야....
# Out:
# Voting 분류기 정확도: 0.9807

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          yes       0.98      0.98      0.98       399
#           no       0.98      0.98      0.98       432
#
#     accuracy                           0.98       831
#    macro avg       0.98      0.98      0.98       831
# weighted avg       0.98      0.98      0.98       831
#
# [[392   7]
#  [  9 423]]

# %% [markdown]
# * 개별모델 예측 평가

# %%
classifiers = [dt_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train , y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test , pred)))
    
    print(classification_report(y_test,pred,target_names=['yes','no']))
    print(confusion_matrix(y_test,pred),'\n')
    
# 왜 정확도가 같다고 나오지???
# 하나로 찍으니까 그렇게 나오지.

# 참고로, 로지스틱은 정규화 하고 넣어야 한다.
# Out:
# DecisionTreeClassifier 정확도: 0.9759
#               precision    recall  f1-score   support
#
#          yes       0.98      0.97      0.97       399
#           no       0.97      0.98      0.98       432
#
#     accuracy                           0.98       831
#    macro avg       0.98      0.98      0.98       831
# weighted avg       0.98      0.98      0.98       831
#
# [[387  12]
#  [  8 424]]
#
# KNeighborsClassifier 정확도: 0.9025
#               precision    recall  f1-score   support
#
#          yes       0.92      0.87      0.90       399
#           no       0.89      0.93      0.91       432
#
#     accuracy                           0.90       831
#    macro avg       0.90      0.90      0.90       831
# weighted avg       0.90      0.90      0.90       831
#
# [[347  52]
#  [ 29 403]]

# %% [markdown]
# ### 6.1.2. 랜덤포레스트로 예측

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9976

# %%
ftr_importances = pd.Series(rf_clf.feature_importances_,index=df_removed1.columns[0:-1])

ftr_importances.sort_values(ascending = False).to_frame()
# Out:
#                         0
# 역마진여부            0.083477
# 유효이자율            0.082435
# 매출총이익률           0.071569
# 매출채권회전율          0.069222
# 총자산대비매출채권        0.059198
# 단기역마진여부          0.057483
# 단기금융자산수익률        0.051984
# 총자산대비유형자산        0.043808
# 산업평균대비매출채권       0.041392
# 산업평균대비재고         0.039216
# 산업평균대비유형자산       0.036299
# 산업평균대비차입금        0.035826
# 산업평균대비유형자산감가상각률  0.033900
# 유형자산감가상각률        0.031222
# 재고자산회전율          0.029077
# 총자산대비차입금         0.028865
# 총자산대비단기금융자산      0.026948
# 총자산대비재고          0.026906
# 매출원가율            0.026460
# 산업평균대비현금         0.024779
# 총자산대비현금          0.023163
# 대손률              0.022178
# 총자산대비무형자산        0.014868
# 산업평균대비무형자산상각률    0.010889
# 무형자산상각률          0.010693
# 개발비계상비율          0.009118
# 산업평균대비무형자산       0.009024
# 금융자산수익률          0.000000
# 산업평균대비유가증권       0.000000
# 유가증권수익률          0.000000
# 단기유효이자율          0.000000
# 총자산대비유가증권        0.000000
# 총자산대비금융자산        0.000000

# %%
ftr_importances_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_importances_top20.values , y = ftr_importances_top20.index)
plt.show()

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))

# 랜덤포레스트는 나쁘지 않다.
# Out:
#               precision    recall  f1-score   support
#
#          yes       1.00      1.00      1.00       399
#           no       1.00      1.00      1.00       432
#
#     accuracy                           1.00       831
#    macro avg       1.00      1.00      1.00       831
# weighted avg       1.00      1.00      1.00       831
#
# [[398   1]
#  [  1 431]]

# %% [markdown]
# ### 6.1.3. 로지스틱회귀분석 예측

# %% [markdown]
# * 정규화

# %%
scaler=StandardScaler()
X_scale=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y,test_size=0.3)

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_clf.score(X_test,y_test)

# 성능이 유의적으로 오르긴 하였으나 거의 쓸모가 없음.
# Out:
# 0.8267148014440433

# %% [markdown]
# * Metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
pred = lr_clf.predict(X_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8267148014440433

# %%
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       428
#            1       0.81      0.84      0.83       403
#
#     accuracy                           0.83       831
#    macro avg       0.83      0.83      0.83       831
# weighted avg       0.83      0.83      0.83       831
#
# [[347  81]
#  [ 63 340]]

# %% [markdown]
# ### 6.1.4 서포트벡터머신 예측

# %% [markdown]
# * 서포트벡터머신 : 패턴 인식, 자료 분석을 위한 지도 학습 모델이며, 주로 분류와 회귀 분석을 위해 사용

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
model.score(X_test,y_test)

# 이상치 제거 전후가 왜 이렇게 유의적으로 차이가 나는거지?

# 서포트벡터머신의 결과가 좋다면 군집분석도 된다는 것 아니냐?
# Out:
# 0.9073405535499398

# %%
svc_predict=model.predict(X_test)

# %%
print(classification_report(y_test, svc_predict))
print(confusion_matrix(y_test,svc_predict))

# 개수 보면 오류는 아니다.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       428
#            1       0.88      0.94      0.91       403
#
#     accuracy                           0.91       831
#    macro avg       0.91      0.91      0.91       831
# weighted avg       0.91      0.91      0.91       831
#
# [[375  53]
#  [ 24 379]]

# %% [markdown]
# ### 6.1.5. 인공신경망으로 예측

# %% [markdown]
# * Minmax scaling

# %%
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , random_state= 156)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2214, 33), (554, 33), (2214,), (554,))

# %% [markdown]
# * 모형생성 및 학습

# %%
model=models.Sequential()
model.add(layers.Dense(4, activation='relu',input_dim=X_train.shape[1]))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 136
#
#  dense_1 (Dense)             (None, 4)                 20
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# 혹시 학습 정의의 문제인가? 그럼 어떻게 바꿔야 하는데

# %%
history=model.fit(X_train,y_train,
                 epochs=200,batch_size=128,
                 validation_split=0.3, class_weight={0:1,1:1}) # class_weight={0:0.0506,1:1} 

# smote 했으므로 가중치 1:1 로 학습.
# Out:
# Epoch 1/200
# 13/13 [==============================] - 2s 49ms/step - loss: 0.6846 - accuracy: 0.6398 - val_loss: 0.6840 - val_accuracy: 0.6632
# Epoch 2/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6804 - accuracy: 0.6869 - val_loss: 0.6803 - val_accuracy: 0.6767
# Epoch 3/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6752 - accuracy: 0.7017 - val_loss: 0.6747 - val_accuracy: 0.6947
# Epoch 4/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6679 - accuracy: 0.7185 - val_loss: 0.6686 - val_accuracy: 0.6917
# Epoch 5/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6606 - accuracy: 0.7088 - val_loss: 0.6638 - val_accuracy: 0.6842
# Epoch 6/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6549 - accuracy: 0.7063 - val_loss: 0.6598 - val_accuracy: 0.6782
# Epoch 7/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6497 - accuracy: 0.7043 - val_loss: 0.6556 - val_accuracy: 0.6857
# Epoch 8/200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.6450 - accuracy: 0.7172 - val_loss: 0.6516 - val_accuracy: 0.6947
# Epoch 9/200
# 13/13 [==============================] - 0s 12ms/step - loss: 0.6398 - accuracy: 0.7140 - val_loss: 0.6484 - val_accuracy: 0.6466
# Epoch 10/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6347 - accuracy: 0.7017 - val_loss: 0.6437 - val_accuracy: 0.6752
# Epoch 11/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6294 - accuracy: 0.7121 - val_loss: 0.6402 - val_accuracy: 0.6451
# Epoch 12/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6242 - accuracy: 0.6927 - val_loss: 0.6347 - val_accuracy: 0.6977
# Epoch 13/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6190 - accuracy: 0.7101 - val_loss: 0.6310 - val_accuracy: 0.6707
# Epoch 14/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6134 - accuracy: 0.7121 - val_loss: 0.6267 - val_accuracy: 0.6677
# Epoch 15/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6080 - accuracy: 0.7127 - val_loss: 0.6214 - val_accuracy: 0.6962
# Epoch 16/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6021 - accuracy: 0.7121 - val_loss: 0.6171 - val_accuracy: 0.6977
# Epoch 17/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.5970 - accuracy: 0.7185 - val_loss: 0.6138 - val_accuracy: 0.6632
# Epoch 18/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5914 - accuracy: 0.7134 - val_loss: 0.6121 - val_accuracy: 0.6541
# Epoch 19/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5869 - accuracy: 0.6979 - val_loss: 0.6070 - val_accuracy: 0.6586
# Epoch 20/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5821 - accuracy: 0.7056 - val_loss: 0.6014 - val_accuracy: 0.6977
# Epoch 21/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5776 - accuracy: 0.7192 - val_loss: 0.5979 - val_accuracy: 0.6917
# Epoch 22/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.
200
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3353 - accuracy: 0.8864 - val_loss: 0.3789 - val_accuracy: 0.8556
# Epoch 179/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3348 - accuracy: 0.8870 - val_loss: 0.3761 - val_accuracy: 0.8391
# Epoch 180/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3335 - accuracy: 0.8877 - val_loss: 0.3759 - val_accuracy: 0.8466
# Epoch 181/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3328 - accuracy: 0.8883 - val_loss: 0.3773 - val_accuracy: 0.8436
# Epoch 182/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3318 - accuracy: 0.8857 - val_loss: 0.3748 - val_accuracy: 0.8451
# Epoch 183/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3315 - accuracy: 0.8877 - val_loss: 0.3759 - val_accuracy: 0.8436
# Epoch 184/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3297 - accuracy: 0.8870 - val_loss: 0.3791 - val_accuracy: 0.8632
# Epoch 185/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3301 - accuracy: 0.8903 - val_loss: 0.3737 - val_accuracy: 0.8466
# Epoch 186/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3280 - accuracy: 0.8883 - val_loss: 0.3743 - val_accuracy: 0.8436
# Epoch 187/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3261 - accuracy: 0.8877 - val_loss: 0.3723 - val_accuracy: 0.8481
# Epoch 188/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3269 - accuracy: 0.8896 - val_loss: 0.3706 - val_accuracy: 0.8436
# Epoch 189/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3260 - accuracy: 0.8896 - val_loss: 0.3731 - val_accuracy: 0.8632
# Epoch 190/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3259 - accuracy: 0.8877 - val_loss: 0.3681 - val_accuracy: 0.8421
# Epoch 191/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3244 - accuracy: 0.8870 - val_loss: 0.3726 - val_accuracy: 0.8586
# Epoch 192/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3254 - accuracy: 0.8890 - val_loss: 0.3705 - val_accuracy: 0.8481
# Epoch 193/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3230 - accuracy: 0.8896 - val_loss: 0.3728 - val_accuracy: 0.8436
# Epoch 194/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3218 - accuracy: 0.8864 - val_loss: 0.3697 - val_accuracy: 0.8511
# Epoch 195/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3221 - accuracy: 0.8877 - val_loss: 0.3662 - val_accuracy: 0.8436
# Epoch 196/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3213 - accuracy: 0.8870 - val_loss: 0.3647 - val_accuracy: 0.8526
# Epoch 197/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3190 - accuracy: 0.8896 - val_loss: 0.3687 - val_accuracy: 0.8406
# Epoch 198/200
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3189 - accuracy: 0.8903 - val_loss: 0.3639 - val_accuracy: 0.8436
# Epoch 199/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3173 - accuracy: 0.8877 - val_loss: 0.3619 - val_accuracy: 0.8526
# Epoch 200/200
# 13/13 [==============================] - 0s 10ms/step - loss: 0.3179 - accuracy: 0.8890 - val_loss: 0.3666 - val_accuracy: 0.8466

# %%
predicted_result=model.predict(X_test)
predicted_result.shape
# Out:
# 18/18 [==============================] - 0s 2ms/step
# (554, 1)

# %%
predicted_target=pd.Series([1 if predicted_result[i]> 0.5 \
         else 0 for i in range(0,predicted_result.shape[0])])

# %%
accuracy = accuracy_score(y_test , predicted_target)
print('인공신경망 정확도: {0:.4f}'.format(accuracy))
# Out:
# 인공신경망 정확도: 0.8502

# %%
print(classification_report(y_test,predicted_target,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,predicted_target))

# 정확도만 높고 나머지는 병신인데? 이유가 뭐냐
# 해당 피쳐들로는 맞는것을 고르기는 쉬운데 아닌 것을 고르는게 거의 불가능.

# 아니 왜 하나로 쳐 미는데...
# => 점수를 이런 식으로 주면 19:1 의 비율로 존재하므로 한 값으로 밀어도 95점이 나오는 것. 그래서 이렇게...
# Out:
#               precision    recall  f1-score   support
#
#          yes       0.91      0.76      0.83       268
#           no       0.81      0.93      0.87       286
#
#     accuracy                           0.85       554
#    macro avg       0.86      0.85      0.85       554
# weighted avg       0.86      0.85      0.85       554
#
# [[205  63]
#  [ 20 266]]

# %%
history_dict=history.history
history_dict.keys()

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)

# %%
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# 이상치 때문으로 보임

# %%
plt.plot(epochs,acc,'bo',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %% [markdown]
# ## 6.2 1% 없앤 데이터 학습

# %% [markdown]
# * SMOTE 를 이용하여 오버샘플링

# %%
X=df_removed2.drop(labels=['감사의견'], axis=1)
y=df_removed2['감사의견']

# %%
oversample = SMOTE()
X,y=oversample.fit_resample(X,y)

# %%
X.shape, y.shape 
# df_removed2.shape : (2091, 34)
# X.shape[0]/df_removed2.shape[0] : 1.9560019129603061
# Out:
# ((2672, 33), (2672,))

# %%
sns.countplot(x=y)
# Out:
# <AxesSubplot:xlabel='감사의견', ylabel='count'>

# %% [markdown]
# * 학습에 사용할 피쳐 선택

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectFromModel, mutual_info_classif, f_classif, SelectKBest

# %%
feature_selection=SelectKBest(f_classif,k=20).fit(X,y)
selected_features=X.columns[feature_selection.get_support()]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3)

# %%
for i in [X_train, X_test, y_train, y_test]:
    print(i.shape)
# Out:
# (1870, 33)
# (802, 33)
# (1870,)
# (802,)

# %% [markdown]
# ### 6.2.1. 앙상블 보팅으로 예측

# %%
dt_clf = DecisionTreeClassifier()
knn_clf = KNeighborsClassifier(n_neighbors=8)

vo_clf = VotingClassifier( estimators=[('DT',dt_clf),('KNN',knn_clf)] , voting='soft' )

# %%
vo_clf.fit(X_train , y_train)
# Out:
# VotingClassifier(estimators=[('DT', DecisionTreeClassifier()),
#                              ('KNN', KNeighborsClassifier(n_neighbors=8))],
#                  voting='soft')

# %%
pred = vo_clf.predict(X_test)
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))

# 정확도가 올라갔다... 왜?
# 1% 만 제거하면 오히려 제거 전보다 정확도가 내려간다.왜???
# Out:
# Voting 분류기 정확도: 0.9838

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#          yes       0.98      0.98      0.98       397
#           no       0.98      0.99      0.98       405
#
#     accuracy                           0.98       802
#    macro avg       0.98      0.98      0.98       802
# weighted avg       0.98      0.98      0.98       802
#
# [[390   7]
#  [  6 399]]

# %% [markdown]
# * 개별모델 예측 평가

# %%
classifiers = [dt_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train , y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test , pred)))
    
    print(classification_report(y_test,pred,target_names=['yes','no']))
    print(confusion_matrix(y_test,pred),'\n')
    
# 왜 정확도가 같다고 나오지???
# 하나로 찍으니까 그렇게 나오지.

# 참고로, 로지스틱은 정규화 하고 넣어야 한다.
# Out:
# DecisionTreeClassifier 정확도: 0.9763
#               precision    recall  f1-score   support
#
#          yes       0.98      0.97      0.98       397
#           no       0.97      0.99      0.98       405
#
#     accuracy                           0.98       802
#    macro avg       0.98      0.98      0.98       802
# weighted avg       0.98      0.98      0.98       802
#
# [[384  13]
#  [  6 399]]
#
# KNeighborsClassifier 정확도: 0.9140
#               precision    recall  f1-score   support
#
#          yes       0.96      0.86      0.91       397
#           no       0.88      0.97      0.92       405
#
#     accuracy                           0.91       802
#    macro avg       0.92      0.91      0.91       802
# weighted avg       0.92      0.91      0.91       802
#
# [[341  56]
#  [ 13 392]]

# %% [markdown]
# ### 6.2.2. 랜덤포레스트로 예측

# %%
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9963

# %%
ftr_importances = pd.Series(rf_clf.feature_importances_,index=df_removed1.columns[0:-1])

top_ftr_importances = ftr_importances.sort_values(ascending = False).to_frame()
top_ftr_importances
# Out:
#                         0
# 유효이자율            0.095368
# 역마진여부            0.094557
# 총자산대비무형자산        0.088588
# 산업평균대비차입금        0.066032
# 총자산대비차입금         0.059414
# 총자산대비단기금융자산      0.055624
# 산업평균대비재고         0.048208
# 총자산대비유형자산        0.046454
# 산업평균대비유형자산       0.045391
# 총자산대비재고          0.040846
# 재고자산회전율          0.034899
# 총자산대비현금          0.032890
# 산업평균대비현금         0.028902
# 매출원가율            0.028131
# 단기금융자산수익률        0.025662
# 매출채권회전율          0.022749
# 산업평균대비무형자산상각률    0.021942
# 무형자산상각률          0.021297
# 매출총이익률           0.020906
# 단기역마진여부          0.020857
# 산업평균대비유형자산감가상각률  0.019452
# 유형자산감가상각률        0.016518
# 산업평균대비무형자산       0.013929
# 개발비계상비율          0.013623
# 총자산대비매출채권        0.013128
# 산업평균대비매출채권       0.012850
# 대손률              0.011783
# 금융자산수익률          0.000000
# 산업평균대비유가증권       0.000000
# 총자산대비금융자산        0.000000
# 단기유효이자율          0.000000
# 총자산대비유가증권        0.000000
# 유가증권수익률          0.000000

# %%
top_index = top_ftr_importances.index[:6]
top_index
# Out:
# Index(['유효이자율', '역마진여부', '총자산대비무형자산', '산업평균대비차입금', '총자산대비차입금', '총자산대비단기금융자산'], dtype='object')

# %%
for i in top_index:
    sns.boxplot(x= '감사의견', y= i , data=df_removed2)
    plt.show()

# %%
import math

plt.rcParams["font.size"]=14

def draw_boxplot(dataset, columns, horizental_number, vertical_number):
        
    for j in range(vertical_number):
        cols = columns[j*horizental_number:(j+1)*horizental_number]

        n=0
        f, axes = plt.subplots(ncols=horizental_number, figsize=(12,8/horizental_number))

        for i in cols:
            sns.boxplot(x= '감사의견', y= i , data=dataset, ax=axes[n])
            axes[n].set_title(i, fontsize=16)
            axes[n].set_ylabel("")
            
            n=n+1
        plt.show()

horizental_number = 3
draw_boxplot(df_removed2, top_index, horizental_number, math.ceil(len(top_index)/horizental_number))

# %%
ftr_importances_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances')
sns.barplot(x=ftr_importances_top20.values , y = ftr_importances_top20.index)
plt.show()

# %%
print(classification_report(y_test,pred,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,pred))

# 랜덤포레스트는 나쁘지 않다.
# Out:
#               precision    recall  f1-score   support
#
#          yes       1.00      0.99      1.00       397
#           no       1.00      1.00      1.00       405
#
#     accuracy                           1.00       802
#    macro avg       1.00      1.00      1.00       802
# weighted avg       1.00      1.00      1.00       802
#
# [[395   2]
#  [  1 404]]

# %% [markdown]
# ### 6.1.3. 로지스틱회귀분석 예측

# %% [markdown]
# * 정규화

# %%
scaler=StandardScaler()
X_scale=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scale, y,test_size=0.3)

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression()
lr_clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_clf.score(X_test,y_test)

# 성능이 유의적으로 오르긴 하였으나 거의 쓸모가 없음.
# Out:
# 0.8354114713216958

# %% [markdown]
# * Metrics

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
pred = lr_clf.predict(X_test)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8354114713216958

# %%
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))

# 인공신경망과 로지스틱회귀분석은 거의 유사한 방식이다. 
# 이쪽 류는 예측에 그다지 도움이 안되는데 왜?
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       381
#            1       0.85      0.83      0.84       421
#
#     accuracy                           0.84       802
#    macro avg       0.83      0.84      0.84       802
# weighted avg       0.84      0.84      0.84       802
#
# [[320  61]
#  [ 71 350]]

# %% [markdown]
# ### 6.1.4 서포트벡터머신 예측

# %% [markdown]
# * 서포트벡터머신 : 패턴 인식, 자료 분석을 위한 지도 학습 모델이며, 주로 분류와 회귀 분석을 위해 사용

# %%
from sklearn.svm import SVC

# %%
model = SVC()
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
model.score(X_test,y_test)

# 이상치 제거 전후가 왜 이렇게 유의적으로 차이가 나는거지?

# 여기도 마찬가지로 오히려 더 내려감.
# Out:
# 0.9850374064837906

# %%
svc_predict=model.predict(X_test)

# %%
print(classification_report(y_test, svc_predict))
print(confusion_matrix(y_test,svc_predict))

# 개수 보면 오류는 아니다.
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98       381
#            1       0.97      1.00      0.99       421
#
#     accuracy                           0.99       802
#    macro avg       0.99      0.98      0.98       802
# weighted avg       0.99      0.99      0.99       802
#
# [[369  12]
#  [  0 421]]

# %% [markdown]
# ### 6.1.5. 인공신경망으로 예측

# %% [markdown]
# * Minmax scaling

# %%
scaler = preprocessing.MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , random_state= 156)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2137, 33), (535, 33), (2137,), (535,))

# %% [markdown]
# * 모형생성 및 학습

# %%
model=models.Sequential()
model.add(layers.Dense(4, activation='relu',input_dim=X_train.shape[1]))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 4)                 136
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 161
# Trainable params: 161
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,
                 epochs=200,batch_size=128,
                 validation_split=0.3, class_weight={0:1,1:1}) # class_weight={0:0.0506,1:1} 

# smote 했으므로 가중치 1:1 로 학습.
# Out:
# Epoch 1/200
# 12/12 [==============================] - 2s 47ms/step - loss: 0.7094 - accuracy: 0.4903 - val_loss: 0.7043 - val_accuracy: 0.4938
# Epoch 2/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.7023 - accuracy: 0.5017 - val_loss: 0.6995 - val_accuracy: 0.5047
# Epoch 3/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6969 - accuracy: 0.5211 - val_loss: 0.6947 - val_accuracy: 0.5389
# Epoch 4/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6915 - accuracy: 0.5813 - val_loss: 0.6898 - val_accuracy: 0.6075
# Epoch 5/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6862 - accuracy: 0.6288 - val_loss: 0.6851 - val_accuracy: 0.6199
# Epoch 6/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6809 - accuracy: 0.6508 - val_loss: 0.6803 - val_accuracy: 0.6449
# Epoch 7/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6755 - accuracy: 0.6676 - val_loss: 0.6753 - val_accuracy: 0.6698
# Epoch 8/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6702 - accuracy: 0.6936 - val_loss: 0.6706 - val_accuracy: 0.6978
# Epoch 9/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6647 - accuracy: 0.7090 - val_loss: 0.6657 - val_accuracy: 0.7103
# Epoch 10/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6593 - accuracy: 0.7191 - val_loss: 0.6608 - val_accuracy: 0.7243
# Epoch 11/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6538 - accuracy: 0.7324 - val_loss: 0.6557 - val_accuracy: 0.7461
# Epoch 12/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6481 - accuracy: 0.7472 - val_loss: 0.6505 - val_accuracy: 0.7461
# Epoch 13/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6423 - accuracy: 0.7572 - val_loss: 0.6457 - val_accuracy: 0.7492
# Epoch 14/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6365 - accuracy: 0.7686 - val_loss: 0.6397 - val_accuracy: 0.7617
# Epoch 15/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.6301 - accuracy: 0.7766 - val_loss: 0.6335 - val_accuracy: 0.7710
# Epoch 16/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.6235 - accuracy: 0.7786 - val_loss: 0.6274 - val_accuracy: 0.7788
# Epoch 17/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.6166 - accuracy: 0.7886 - val_loss: 0.6208 - val_accuracy: 0.7928
# Epoch 18/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.6092 - accuracy: 0.7940 - val_loss: 0.6140 - val_accuracy: 0.7928
# Epoch 19/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.6017 - accuracy: 0.7860 - val_loss: 0.6068 - val_accuracy: 0.7913
# Epoch 20/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5934 - accuracy: 0.7866 - val_loss: 0.5980 - val_accuracy: 0.7913
# Epoch 21/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5848 - accuracy: 0.7860 - val_loss: 0.5893 - val_accuracy: 0.7882
# Epoch 22/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5766 - accuracy: 0.7826 - val_loss: 0.5810 - val_accuracy: 0.7913
# Epoch 23/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5680 - accuracy: 0.7866 - val_loss: 0.5728 - val_accuracy: 0.8006
# Epoch 24/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5594 - accuracy: 0.7987 - val_loss: 0.5642 - val_accuracy: 0.8069
# Epoch 25/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5505 - accuracy: 0.8033 - val_loss: 0.5545 - val_accuracy: 0.8053
# Epoch 26/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5416 - accuracy: 0.8040 - val_loss: 0.5464 - val_accuracy: 0.8255
# Epoch 27/200
# 12/12 [==============================] - 0s 12ms/step - loss: 0.5327 - accuracy: 0.8040 - val_loss: 0.5374 - val_accuracy: 0.8302
# Epoch 28/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.
200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2338 - accuracy: 0.9157 - val_loss: 0.2289 - val_accuracy: 0.9299
# Epoch 184/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2326 - accuracy: 0.9171 - val_loss: 0.2297 - val_accuracy: 0.9190
# Epoch 185/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2321 - accuracy: 0.9184 - val_loss: 0.2289 - val_accuracy: 0.9237
# Epoch 186/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2318 - accuracy: 0.9164 - val_loss: 0.2277 - val_accuracy: 0.9252
# Epoch 187/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2305 - accuracy: 0.9184 - val_loss: 0.2263 - val_accuracy: 0.9315
# Epoch 188/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2296 - accuracy: 0.9211 - val_loss: 0.2262 - val_accuracy: 0.9268
# Epoch 189/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2289 - accuracy: 0.9137 - val_loss: 0.2230 - val_accuracy: 0.9393
# Epoch 190/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2284 - accuracy: 0.9217 - val_loss: 0.2249 - val_accuracy: 0.9283
# Epoch 191/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2275 - accuracy: 0.9204 - val_loss: 0.2224 - val_accuracy: 0.9330
# Epoch 192/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2262 - accuracy: 0.9197 - val_loss: 0.2202 - val_accuracy: 0.9377
# Epoch 193/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2260 - accuracy: 0.9244 - val_loss: 0.2217 - val_accuracy: 0.9330
# Epoch 194/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2251 - accuracy: 0.9251 - val_loss: 0.2223 - val_accuracy: 0.9330
# Epoch 195/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2249 - accuracy: 0.9244 - val_loss: 0.2189 - val_accuracy: 0.9377
# Epoch 196/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2235 - accuracy: 0.9231 - val_loss: 0.2201 - val_accuracy: 0.9315
# Epoch 197/200
# 12/12 [==============================] - 0s 13ms/step - loss: 0.2229 - accuracy: 0.9231 - val_loss: 0.2197 - val_accuracy: 0.9315
# Epoch 198/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2218 - accuracy: 0.9258 - val_loss: 0.2225 - val_accuracy: 0.9252
# Epoch 199/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2215 - accuracy: 0.9184 - val_loss: 0.2154 - val_accuracy: 0.9408
# Epoch 200/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2212 - accuracy: 0.9271 - val_loss: 0.2173 - val_accuracy: 0.9361

# %%
predicted_result=model.predict(X_test)
predicted_result.shape
# Out:
# 17/17 [==============================] - 0s 2ms/step
# (535, 1)

# %%
predicted_target=pd.Series([1 if predicted_result[i]> 0.5 \
         else 0 for i in range(0,predicted_result.shape[0])])

# %%
accuracy = accuracy_score(y_test , predicted_target)
print('인공신경망 정확도: {0:.4f}'.format(accuracy))
# Out:
# 인공신경망 정확도: 0.9084

# %%
print(classification_report(y_test,predicted_target,\
         target_names=['yes','no']))
print(confusion_matrix(y_test,predicted_target))

# 정확도만 높고 나머지는 병신인데? 이유가 뭐냐
# 해당 피쳐들로는 맞는것을 고르기는 쉬운데 아닌 것을 고르는게 거의 불가능.

# 아니 왜 하나로 쳐 미는데...
# => 점수를 이런 식으로 주면 19:1 의 비율로 존재하므로 한 값으로 밀어도 95점이 나오는 것. 그래서 이렇게...
# Out:
#               precision    recall  f1-score   support
#
#          yes       0.94      0.86      0.90       256
#           no       0.88      0.95      0.92       279
#
#     accuracy                           0.91       535
#    macro avg       0.91      0.91      0.91       535
# weighted avg       0.91      0.91      0.91       535
#
# [[220  36]
#  [ 13 266]]

# %%
history_dict=history.history
history_dict.keys()

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(acc)+1)

# %%
plt.plot(epochs,loss,'bo',label='Training loss')
plt.plot(epochs,val_loss,'b',label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
plt.plot(epochs,acc,'bo',label='Training accuracy')
plt.plot(epochs,val_acc,'b',label='Validation accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()
